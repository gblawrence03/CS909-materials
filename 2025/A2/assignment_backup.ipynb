# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Question 1 - Data Analysis](#toc1_)
#   - [i) Counting Examples](#toc1_1_)
#   - [ii) Protein Expression Histograms](#toc1_2_)
#   - [iii) Image Preprocessing](#toc1_3_)
#   - [iv) Channel Correlation with CD11b Expression](#toc1_4_)
#   - [v) Blue vs H Channels](#toc1_5_)
# - [Question 2](#toc2_)
#   - [i) Feature Selection](#toc2_1_)
#     - [PCA On all RGB Channels](#toc2_1_1_)
#     - [PCA on all HED channels](#toc2_1_2_)
#     - [Mean and Variance](#toc2_1_3_)
#     - [Histogram of Gradients](#toc2_1_4_)
#     - [GLCM](#toc2_1_5_)
#     - [Local Binary Pattern](#toc2_1_6_)
#   - [Regression Models](#toc2_2_)
#     - [Linear Regression](#toc2_2_1_)
#     - [Random Forest](#toc2_2_2_)
#     - [SVC](#toc2_2_3_)
# - [Question 3](#toc3_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# !pip install tqdm # for progress bars
# !pip install seaborn # for barplot
# !pip install opencv-python # for image manipulation
# Out:
# Requirement already satisfied: tqdm in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (4.67.1)
# Requirement already satisfied: seaborn in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: pandas>=1.2 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: opencv-python in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /dcs/21/u2101693/modules/cs429/CS909-materials/.venv/lib64/python3.12/site-packages (from opencv-python) (2.2.1)

# %% [markdown]
# # <a id='toc1_'></a>[Question 1 - Data Analysis](#toc0_)
#
# ## <a id='toc1_1_'></a>[i) Counting Examples](#toc0_)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('https://warwick.ac.uk/fac/sci/dcs/teaching/material/cs909/protein_expression_data.csv')

df['specimen_id']=df.VisSpot.apply(lambda x: x.split('-')[2]) #create specimen id field
df['image_id']=df.VisSpot.apply(lambda x: x.split('-')[2])+'_'+df.id #create image id field
train_specimens = ['B1', 'C1', 'D1']
df = df.set_index('image_id').sort_index()
protein_names = ['SMAa', 'CD11b',
       'CD44', 'CD31', 'CDK4', 'YKL40', 'CD11c', 'HIF1a', 'CD24', 'TMEM119',
       'OLIG2', 'GFAP', 'VISTA', 'IBA1', 'CD206', 'PTEN', 'NESTIN', 'TCIRG1',
       'CD74', 'MET', 'P2RY12', 'CD163', 'S100B', 'cMYC', 'pERK', 'EGFR',
       'SOX2', 'HLADR', 'PDGFRa', 'MCT4', 'DNA1', 'DNA3', 'MHCI', 'CD68',
       'CD14', 'KI67', 'CD16', 'SOX10']

# %% [markdown]
# Let's first separate the training and test data.

# %%
df_train = df.loc[df['specimen_id'].isin(train_specimens)]
df_test = df.loc[df['specimen_id'] == 'A1']

df_train['CD11b'].describe()
# Out:
# count    7027.000000
# mean       -1.584007
# std         1.481296
# min        -4.782092
# 25%        -2.794762
# 50%        -1.180678
# 75%        -0.321114
# max         1.761779
# Name: CD11b, dtype: float64

# %% [markdown]
# The number of spots of each specimen in the training set are given below:

# %%
df_train.groupby('specimen_id')['specimen_id'].value_counts()
# Out:
# specimen_id
# B1    1145
# C1    4129
# D1    1753
# Name: count, dtype: int64

# %% [markdown]
# ## <a id='toc1_2_'></a>[ii) Protein Expression Histograms](#toc0_)

# %%
fig, axes = plt.subplots(1, 3)
fig.set_figheight(4)
fig.set_figwidth(12)

for i, ax in enumerate(axes.flatten()):
    specimen = train_specimens[i]
    df_train.loc[df_train['specimen_id'] == specimen].hist('CD11b', ax=ax, bins=25)
    ax.set_title(f"Specimen {specimen}")

    ax.set_xlabel('CD11b expression value')
    if (i == 0):
        ax.set_ylabel('Frequency')
    ax.set_xlim((-5, 2))
    #ax.set_ylim((0, 1050)) # If we want all histograms to be on the same scale
    ax.grid(visible=False, axis='x')
    
fig.suptitle('CD11b Expression Values by Specimen')
# Out:
# Text(0.5, 0.98, 'CD11b Expression Values by Specimen')

# %% [markdown]
# We notice that specimen B1 and C1 have similar distributions of the expression value of protein CD11b, with peaks at around 0 and tails to the left down to -5. Specimen D1 has two peaks at -4 and 0.

# %%
fig, axes = plt.subplots(1, 3)
fig.set_figheight(4)
fig.set_figwidth(12)

for i, ax in enumerate(axes.flatten()):
    specimen = train_specimens[i]
    df_train.loc[df_train['specimen_id'] == specimen].hist('CD11b', ax=ax, bins=75)
    ax.set_title(f"Specimen {specimen}")

    ax.set_xlabel('CD11b expression value')
    if (i == 0):
        ax.set_ylabel('Frequency')
    ax.set_xlim((-5, 2))
    #ax.set_ylim((0, 1050)) # If we want all histograms to be on the same scale
    ax.grid(visible=False, axis='x')
    
fig.suptitle('CD11b Expression Values by Specimen')
# Out:
# Text(0.5, 0.98, 'CD11b Expression Values by Specimen')

# %% [markdown]
# If we plot using more bins, we also notice that all three specimen have a peak at a very specific value on the left. This is interesting because there appear to be no expression values to the left of these peaks.

# %%
df_train[['specimen_id', 'CD11b']].value_counts()
# Out:
# specimen_id  CD11b
# C1           -4.782092    104
# D1           -4.376121     90
# B1           -4.731601     40
# C1           -4.402024      2
#              -0.155368      1
#                          ...
#              -2.256882      1
#              -2.259379      1
#              -2.261223      1
#              -2.261946      1
#              -2.240232      1
# Name: count, Length: 6795, dtype: int64

# %% [markdown]
# We can see the peaks in the above value counts. The frequency peaks are at very specific values, whereas all (except one) other values have a frequency of 1. Plus, there are no values below the peaks. One possible explanation for this suggests that maybe originally there were values below the peaks, but they were for some reason all grouped into that one peak value.
#
# ## <a id='toc1_3_'></a>[iii) Image Preprocessing](#toc0_)

# %%
image_folder = '/content/patches_256/'
from skimage.feature import local_binary_pattern, hog, graycomatrix, graycoprops
from skimage.color import rgb2gray, rgba2rgb, rgb2hed
from skimage.io import imread
from skimage.util import img_as_ubyte
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from scipy.stats import spearmanr, pearsonr
import matplotlib.pyplot as plt
import os
import glob

# %%
plt.figure(figsize=[14, 6])
for i, im_id in enumerate(np.random.choice(df_train.index, size=10, replace=False)):
    row = df_train.loc[im_id]
    path = os.getcwd()+image_folder+im_id + '.png'
    I = imread(path)
    if I.shape[2] == 4: # It's an RGBA image
        I = rgba2rgb(I)
    I_hed = rgb2hed(I)
    I_h = I_hed[:,:,0]; 
    plt.subplot(2, 5, i+1)
    plt.imshow(I_h,cmap='gray', vmin=0,vmax=0.3);  
    plt.colorbar();  
    plt.title(f'img {im_id}, {row['specimen_id']}')
    plt.axis('off')
plt.suptitle('H Channel Examples')
plt.show()

# %% [markdown]
# ## <a id='toc1_4_'></a>[iv) Channel Correlation with CD11b Expression](#toc0_)

# %%
from tqdm import tqdm

def images_from_ids(im_ids):
    imgs = []
    for im_id in tqdm(im_ids):
        path = os.getcwd()+image_folder+im_id+'.png'
        I = plt.imread(path)
        if I.shape[2] == 4: # it's an RGBA image 
            I = rgba2rgb(I)
        imgs.append(I)
    return np.array(imgs)     

def images_to_HED(X): 
    X_HED = np.zeros_like(X)
    for i in range(X.shape[0]):
        X_HED[i] = rgb2hed(X[i])
    return X_HED

X_train = images_from_ids(df_train.index)
y_train = df_train['CD11b']
print("Loading testing images")
X_test = images_from_ids(df_test.index)
y_test = df_test['CD11b']   

X_HED_train = images_to_HED(X_train)
X_HED_test = images_to_HED(X_test)
# Out:
# 100%|██████████| 7027/7027 [00:27<00:00, 260.16it/s]
# Loading testing images
# 100%|██████████| 2894/2894 [00:16<00:00, 180.33it/s]

# %%
average_hs = np.mean(X_HED_train[..., 0], axis=(1, 2))
average_bs = np.mean(X_train[..., 2], axis=(1, 2))
average_es = np.mean(X_HED_train[..., 1], axis=(1, 2))
cd11b_values = df_train['CD11b']

b_indices = np.where(df_train['specimen_id'] == 'B1')[0]
c_indices = np.where(df_train['specimen_id'] == 'C1')[0]
d_indices = np.where(df_train['specimen_id'] == 'D1')[0]

print(f"Average H: {np.mean(average_hs)}")
print(f"Average Blue: {np.mean(average_bs)}")
print(f"Average E: {np.mean(average_es)}")
# Out:
# Average H: 0.01624903827905655
# Average Blue: 0.6998291015625
# Average E: 0.03694453462958336

# %%
plt.figure()
ax = plt.gca()

ax.scatter(average_hs[b_indices], cd11b_values.iloc[b_indices], s=3, label='Specimen B1')
ax.scatter(average_hs[c_indices], cd11b_values.iloc[c_indices], s=3, label='Specimen C1')
ax.scatter(average_hs[d_indices], cd11b_values.iloc[d_indices], s=3, label='Specimen D1')
ax.set_xlabel('Average H channel intensity')
ax.set_ylabel('CD11b expression value')
ax.set_title('Average H Channel Intensity vs CD11b Expression Value', fontsize=10)

frame = plt.legend(fontsize=8, frameon=True).get_frame()
frame.set_edgecolor('#444444')


print(f"Spearman correlation of average H channel with CD11b: {spearmanr(average_hs, cd11b_values).statistic}")
print(f"Pearson correlation of average H channel with CD11b: {pearsonr(average_hs, cd11b_values).statistic}")
# Out:
# Spearman correlation of average H channel with CD11b: -0.05841383786379311
# Pearson correlation of average H channel with CD11b: -0.07349653616024004

# %% [markdown]
# There is a very weak negative correlation between the H-channel intensity and the CD11b expression. H-channel intensity is unlikely to have much predictive power for CD11b expression. It explains very little variance in the expression. What we do notice is that each of the three specimen have some separability based on the H-channel. This is significant as it suggests that the test specimen (A1) may also have a different H-channel intensity from the rest. This may indicate that when training models, we need to create our validation sets based on specimen, as this will allow us to evaluate how well our models are able to generalise to different specimens.

# %%
plt.figure()
ax = plt.gca()

ax.scatter(average_es[b_indices], cd11b_values.iloc[b_indices], s=3, label='Specimen B1')
ax.scatter(average_es[c_indices], cd11b_values.iloc[c_indices], s=3, label='Specimen C1')
ax.scatter(average_es[d_indices], cd11b_values.iloc[d_indices], s=3, label='Specimen D1')
ax.set_xlabel('Average E channel intensity')
ax.set_ylabel('CD11b expression value')
ax.set_title('Average E Channel Intensity vs CD11b Expression Value', fontsize=10)

frame = plt.legend(fontsize=8, frameon=True).get_frame()
frame.set_edgecolor('#444444')

print(f"Spearman correlation of average E channel with CD11b: {spearmanr(average_es, cd11b_values).statistic}")
print(f"Pearson correlation of average E channel with CD11b: {pearsonr(average_es, cd11b_values).statistic}")
# Out:
# Spearman correlation of average E channel with CD11b: 0.22886394547521552
# Pearson correlation of average E channel with CD11b: 0.2777624020153875

# %% [markdown]
# There is a weak, but stronger, positive correlation between the E channel and the CD11b expression value. The E channel average may help to predict the CD11b expression. However, there is still a lot of unexplained variance.

# %%
plt.figure()
ax = plt.gca()

ax.scatter(average_bs[b_indices], cd11b_values.iloc[b_indices], s=3, label='Specimen B1')
ax.scatter(average_bs[c_indices], cd11b_values.iloc[c_indices], s=3, label='Specimen C1')
ax.scatter(average_bs[d_indices], cd11b_values.iloc[d_indices], s=3, label='Specimen D1')
ax.set_xlabel('Average Blue channel intensity')
ax.set_ylabel('CD11b expression value')
ax.set_title('Average Blue Channel Intensity vs CD11b Expression Value', fontsize=10)

frame = plt.legend(fontsize=8, frameon=True).get_frame()
frame.set_edgecolor('#444444')

print(f"Spearman correlation of average blue channel with CD11b: {spearmanr(average_bs, cd11b_values).statistic}")
print(f"Pearson correlation of average blue channel with CD11b: {pearsonr(average_bs, cd11b_values).statistic}")
# Out:
# Spearman correlation of average blue channel with CD11b: -0.18122330111291898
# Pearson correlation of average blue channel with CD11b: -0.24146946148509363

# %% [markdown]
# ## <a id='toc1_5_'></a>[v) Blue vs H Channels](#toc0_)

# %%
plt.figure()
ax = plt.gca()

ax.scatter(average_hs[b_indices], average_bs[b_indices], s=3, label='Specimen B1')
ax.scatter(average_hs[c_indices], average_bs[c_indices], s=3, label='Specimen C1')
ax.scatter(average_hs[d_indices], average_bs[d_indices], s=3, label='Specimen D1')
ax.set_xlabel('Average H channel intensity')
ax.set_ylabel('Average Blue channel intensity')
ax.set_title('Average H vs Average Blue channel intensities', fontsize=10)

frame = plt.legend(fontsize=8, frameon=True).get_frame()
frame.set_edgecolor('#444444')

print(spearmanr(average_hs, average_bs).statistic)
print(pearsonr(average_hs, average_bs).statistic)
# Out:
# 0.3878013601645221
# 0.36740568758889813

# %% [markdown]
# We can see that the H channel is able to partially separate out the three specimens, whereas the blue channel is much less able to do this. We can also see that there is some correlation between the H and Blue channels, but it is highly non-linear, which is due to the fact that the H channel is also influenced by the red and green channels. However, we can see that there are limits as to what blue values can be converted to what H values, and the shape roughly appears triangular in the scatter diagram. For example, there are no examples where an average blue channel of 0.9 correlates to an average H channel of 0.03.
#
# We can check for association between protein expression levels by finding the pairwise correlations of each. You can see the result below, with red colours indicating a higher correlation between the proteins. It is evident that there is association between protein expression levels of some pairs of proteins. For example, MET and PDGFRa are quite positively correlated. In fact, the correlations are mostly positvie. There are some pairs that are weakly negatively correlated.
#
# Most significantly, however, we notice that values of H are in general **much lower** (ranging from 0 to 0.04) than values of blue, ranging from 0.4 to 1. This indicates that feature scaling will be necessary when looking for features such as with PCA.

# %%
corr = df_train[protein_names].corr()

plt.figure(figsize=[9, 8])
ax = plt.gca()
corr_ax = ax.matshow(corr, cmap='coolwarm', vmin=-1, vmax=1)
plt.colorbar(corr_ax)
ticks = np.arange(0, len(protein_names))
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(protein_names, fontsize=7, rotation=90)
ax.set_yticklabels(protein_names, fontsize=7);

# %% [markdown]
# # <a id='toc2_'></a>[Question 2](#toc0_)
#
# ## <a id='toc2_1_'></a>[i) Feature Selection](#toc0_)
#
# ### <a id='toc2_1_1_'></a>[PCA On all RGB Channels](#toc0_)

# %% [markdown]
# For all the feature selection questions, we're going to downsample the images to 128x128 pixels (from 256x256), to decrease compute requirements.

# %%
from sklearn.decomposition import PCA
import cv2

# Resize function
def resize_images(X, new_size=(128, 128)):
    """Resizes all images in X to new_size."""
    n_train, _, _, c = X.shape
    X_resized = np.zeros((n_train, new_size[0], new_size[1], c), dtype=X.dtype)

    for i in range(n_train):
        X_resized[i] = cv2.resize(X[i], new_size, interpolation=cv2.INTER_AREA)
    
    return X_resized

X_train = resize_images(X_train)
X_test = resize_images(X_test)
X_HED_train = resize_images(X_HED_train)
X_HED_test = resize_images(X_HED_test)

n_train, width, height, c = X_train.shape

# %% [markdown]
# Using the first image as an example

# %% [markdown]
# ### <a id='toc2_1_2_'></a>[PCA on all HED channels](#toc0_)

# %%
pca = PCA(10)
pcs = pca.fit_transform(X_train.reshape((X_train.shape[0]), -1))

plt.plot(np.arange(1, pca.n_components_ + 1), np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('# components')
plt.ylabel('Explained variance')
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
# Set number of principal components to keep
n_components = 10  # Change this to any desired number of PCs

# Function to scale each channel separately
def scale_all_channels(X):
    """Scales each image channel independently to zero mean, unit variance."""
    n_train, h, w, c = X.shape
    X_scaled = np.zeros((n_train, h*w*c))  # Reshape to [n_train, pixels, channels]
    
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X.reshape(n_train, -1))  # Scale each channel separately
    
    return X_scaled.reshape(n_train, -1)  # Flatten back into [n_train, features]

# Apply per-channel scaling
#X_rgb_scaled = scale_all_channels(X)  # Scale RGB channels independently
#X_hed_scaled = scale_all_channels(X_HED)  # Scale HED channels independently

# Scale individual channels separately before PCA
def scale_single_channel(X_channel):
    """Scales a single-channel image dataset."""
    scaler = StandardScaler()
    return scaler.fit_transform(X_channel.reshape(n_train, -1))

X_r_scaled = scale_single_channel(X_train[..., 0])
X_g_scaled = scale_single_channel(X_train[..., 1])
X_b_scaled = scale_single_channel(X_train[..., 2])
X_h_scaled = scale_single_channel(X_HED_train[..., 0])
X_e_scaled = scale_single_channel(X_HED_train[..., 1])
X_d_scaled = scale_single_channel(X_HED_train[..., 2])

# Perform PCA with a variable number of components
def apply_pca(X_flat):
    return PCA(n_components=n_components).fit_transform(X_flat)

pca_results = {
    #"RGB": apply_pca(X_rgb_scaled),
    #"HED": apply_pca(X_hed_scaled),
    "R": apply_pca(X_r_scaled),
    "G": apply_pca(X_g_scaled),
    "B": apply_pca(X_b_scaled),
    "H": apply_pca(X_h_scaled),
    "E": apply_pca(X_e_scaled),
    "D": apply_pca(X_d_scaled),
}

print(np.array(list(pca_results.values())).shape)
df_pca = pd.DataFrame(np.moveaxis(np.array(list(pca_results.values())), [0, 1, 2], [0, 2, 1]).reshape((6 * n_components, -1)).T)

def compute_pearson(pca_result):
    return [pearsonr(pca_result[:, i], df_train["CD11b"])[0] for i in range(pca_result.shape[1])]

correlations = {key: compute_pearson(pca) for key, pca in pca_results.items()}

# Convert to DataFrame
df_corr = pd.DataFrame(correlations, index=[f"PC{i+1}" for i in range(n_components)])

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", center=0, fmt=".3f", vmin=-0.5, vmax=0.5)
plt.title(f"Pearson Correlation of {n_components} Principal Components with CD11b Expression (Scaled Per-Channel)")
plt.show()
# Out:
# (6, 7027, 10)

# %%
# Compute Pearson correlation with CD11b expression
def compute_spearman(pca_result):
    return [spearmanr(pca_result[:, i], df_train["CD11b"])[0] for i in range(pca_result.shape[1])]

correlations = {key: compute_spearman(pca) for key, pca in pca_results.items()}

# Convert to DataFrame
df_corr = pd.DataFrame(correlations, index=[f"PC{i+1}" for i in range(n_components)])

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", center=0, fmt=".3f", vmin=-0.5, vmax=0.5)
plt.title(f"Spearman Correlation of {n_components} Principal Components with CD11b Expression")
plt.show()

# %% [markdown]
# We hope that the PCA components are able to capture patterns in the pixels of the images. However, the correlations given in the tables above are not promising. The first PC, which likely just captures the mean values of the pixels, is the only one with a significant correlation.

# %% [markdown]
# ### <a id='toc2_1_3_'></a>[Mean and Variance](#toc0_)

# %%
features = {
    "mean_R": np.mean(X_train[..., 0], axis=(1, 2)),  # Mean of Red channel
    "var_R": np.var(X_train[..., 0], axis=(1, 2)),    # Variance of Red channel
    "mean_G": np.mean(X_train[..., 1], axis=(1, 2)),  # Green
    "var_G": np.var(X_train[..., 1], axis=(1, 2)),    
    "mean_B": np.mean(X_train[..., 2], axis=(1, 2)),  # Blue
    "var_B": np.var(X_train[..., 2], axis=(1, 2)),    
    "mean_H": np.mean(X_HED_train[..., 0], axis=(1, 2)),   # H
    "var_H": np.var(X_HED_train[..., 0], axis=(1, 2)),
    "mean_E": np.mean(X_HED_train[..., 1], axis=(1, 2)),   # E
    "var_E": np.var(X_HED_train[..., 1], axis=(1, 2)),
    "mean_D": np.mean(X_HED_train[..., 2], axis=(1, 2)),   # D
    "var_D": np.var(X_HED_train[..., 2], axis=(1, 2)),
}

# Convert to DataFrame
df_mean_var = pd.DataFrame(features)

# Compute Pearson correlation with CD11b
pearson_corr = df_mean_var.apply(lambda x: pearsonr(x, df_train["CD11b"]).correlation).to_frame(name="Pearson Correlation")
spearman_corr = df_mean_var.apply(lambda x: spearmanr(x, df_train["CD11b"]).correlation).to_frame(name="Spearman Correlation")

# Combine both Pearson and Spearman correlation results
df_corr = pd.concat([pearson_corr, spearman_corr], axis=1)

# Reshape to table format (transpose for better readability)
df_corr_table = df_corr.T

# Plot heatmap
color_scale = 0.5  # Adjust for better visualization
plt.figure(figsize=(10, 2))
sns.heatmap(df_corr_table, annot=True, cmap="coolwarm", center=0, fmt=".3f", vmin=-color_scale, vmax=color_scale)
plt.title("Pearson & Spearman Correlation of Mean/Variance Features with CD11b Expression")
plt.show()

# %% [markdown]
# If we compare the correlation values of the mean of each channel with the first PCA component for the respective channels, the values seem to be very similar (if not the same). The variance values also exhibit some correlation. Therefore it's probably wise to exclude the PCs from the final set of features, as the only PC with a high correlation is made redundant by the mean values.
#
# ### <a id='toc2_1_4_'></a>[Histogram of Gradients](#toc0_)

# %% [markdown]
# Histogram of Oriented Gradients (HoG) is useful for capturing local gradient orientation information. The hope is that it will be able to identify useful shapes and textures in the spots.

# %%
# Parameters for HOG
hog_params = {
    "orientations": 9,     
    "pixels_per_cell": (16, 16),  
    "cells_per_block": (2, 2),  # for normalisation
    "feature_vector": True  # flatten features
}

# Compute HOG features for each image
hog_features = []
for img in X_train:
    gray_img = rgb2gray(img)  # Convert RGB to grayscale
    hog_vector = hog(gray_img, **hog_params)  # Compute HOG
    hog_features.append(hog_vector)

# Convert to DataFrame
df_hog = pd.DataFrame(hog_features)

# Compute Pearson and Spearman correlations
pearson_corr = df_hog.apply(lambda x: pearsonr(x, df_train["CD11b"]).correlation).to_frame(name="Pearson Correlation")
spearman_corr = df_hog.apply(lambda x: spearmanr(x, df_train["CD11b"]).correlation).to_frame(name="Spearman Correlation")

# Combine Pearson & Spearman correlation results
df_corr = pd.concat([pearson_corr, spearman_corr], axis=1)

# Select top 10 most correlated (absolute values)
df_corr["Max Abs Corr"] = df_corr.abs().max(axis=1)
df_corr_top10 = df_corr.nlargest(10, "Max Abs Corr").drop(columns=["Max Abs Corr"])

# Plot heatmap
plt.figure(figsize=(10, 2))
sns.heatmap(df_corr_top10.T, annot=True, cmap="coolwarm", center=0, fmt=".3f", vmin=-color_scale, vmax=color_scale)
plt.title("Top 10 Correlated HOG Features with CD11b Expression")
plt.show()

# %% [markdown]
# ### <a id='toc2_1_5_'></a>[GLCM](#toc0_)
#
# GLCM looks at the direction and distance between pairs of images and quantifies how often we can find pairs of intensities at these values. It may be useful for detecting smoothness and contrast in and between cells.

# %%
# Parameters for GLCM
glcm_params = {
    "distances": [1, 2, 3, 5] ,     # Pixel displacements
    "angles": np.pi/4 * np.arange(4)  # Angles
}

# Compute HOG features for each image
glcm_features = []
for img in X_train:
    gray_img = rgb2gray(img)  # Convert RGB to grayscale
    glcm = graycomatrix((255 * gray_img).astype(np.uint8), **glcm_params) 
    glcm_vector = []
    glcm_vector.append(graycoprops(glcm, 'contrast'))
    glcm_vector.append(graycoprops(glcm, 'dissimilarity'))
    glcm_vector.append(graycoprops(glcm, 'homogeneity'))
    glcm_vector.append(graycoprops(glcm, 'energy'))
    glcm_vector.append(graycoprops(glcm, 'correlation'))
    glcm_features.append(np.array(glcm_vector).flatten())

# Convert to DataFrame
df_glcm = pd.DataFrame(glcm_features)

# Compute Pearson and Spearman correlations
pearson_corr = df_glcm.apply(lambda x: pearsonr(x, df_train["CD11b"]).correlation).to_frame(name="Pearson Correlation")
spearman_corr = df_glcm.apply(lambda x: spearmanr(x, df_train["CD11b"]).correlation).to_frame(name="Spearman Correlation")

# Combine Pearson & Spearman correlation results
df_corr = pd.concat([pearson_corr, spearman_corr], axis=1)

# Select top 10 most correlated (absolute values)
df_corr["Max Abs Corr"] = df_corr.abs().max(axis=1)
df_corr_top10 = df_corr.nlargest(10, "Max Abs Corr").drop(columns=["Max Abs Corr"])

# Plot heatmap
plt.figure(figsize=(10, 2))
sns.heatmap(df_corr_top10.T, annot=True, cmap="coolwarm", center=0, fmt=".3f", vmin=-color_scale, vmax=color_scale)
plt.title("Top 10 Correlated GLCM Features with CD11b Expression")
plt.show()

# %% [markdown]
# ### <a id='toc2_1_6_'></a>[Local Binary Pattern](#toc0_)
# We can use LBP to look for very local/small scale texture patterns.

# %%
# Parameters for HOG
lbp_params = {
    "P": 24, #Number of points
    "R": 3,  # Radius of circle
    "method": "uniform"
}

# Compute HOG features for each image
lbp_features = []
for img in X_train:
    gray_img = (255 * rgb2gray(img)).astype(np.uint8)  # Convert RGB to grayscale
    lbp_vector = local_binary_pattern(gray_img, **lbp_params)  # Compute HOG
    lbp_features.append(lbp_vector.flatten())

# Convert to DataFrame
df_lbp = pd.DataFrame(lbp_features)

# Compute Pearson and Spearman correlations
pearson_corr = df_lbp.apply(lambda x: pearsonr(x, df_train["CD11b"]).correlation).to_frame(name="Pearson Correlation")
spearman_corr = df_lbp.apply(lambda x: spearmanr(x, df_train["CD11b"]).correlation).to_frame(name="Spearman Correlation")

# Combine Pearson & Spearman correlation results
df_corr = pd.concat([pearson_corr, spearman_corr], axis=1)

# Select top 10 most correlated (absolute values)
df_corr["Max Abs Corr"] = df_corr.abs().max(axis=1)
df_corr_top10 = df_corr.nlargest(10, "Max Abs Corr").drop(columns=["Max Abs Corr"])

# Plot heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(df_corr_top10.T, annot=True, cmap="coolwarm", center=0, fmt=".3f", vmin=-color_scale, vmax=color_scale)
plt.title("Top 10 Correlated LBP Features with CD11b Expression")
plt.show()

# %% [markdown]
# ## <a id='toc2_2_'></a>[Regression Models](#toc0_)
#
# ### <a id='toc2_2_1_'></a>[Linear Regression](#toc0_)
#
# The appropriate metric would be RMSE or MSE. I'm going to use RMSE as it keeps the error on the same scale as the target variable, making it easier to interpret.
#
# First we'll consolidate all the feature extraction into one method. Since each method of feature extraction works on each image independently, we can safely apply the feature extraction to all the images once, without worrying about data leakage.

# %%
results_df = pd.DataFrame(columns=["model", "r2", "RMSE", "Pearson", "Spearman"])

# %%
def extract_features(X):
    # Compute HOG, GLCM, LBP features for each image
    hog_features = []
    glcm_features = []
    lbp_features = []
    for img in tqdm(X):
        gray_img = rgb2gray(img)  # Convert RGB to grayscale
        int_gray_img = (255 * gray_img).astype(np.uint8)

        # HoG
        hog_vector = hog(gray_img, **hog_params)
        hog_features.append(hog_vector)
        
        # GLCM
        glcm = graycomatrix(int_gray_img, **glcm_params) 
        glcm_vector = []
        glcm_vector.append(graycoprops(glcm, 'contrast'))
        glcm_vector.append(graycoprops(glcm, 'dissimilarity'))
        glcm_vector.append(graycoprops(glcm, 'homogeneity'))
        glcm_vector.append(graycoprops(glcm, 'energy'))
        glcm_vector.append(graycoprops(glcm, 'correlation'))
        glcm_features.append(np.array(glcm_vector).flatten())

        # LBP
        lbp_vector = local_binary_pattern(int_gray_img, **lbp_params)
        lbp_features.append(lbp_vector.flatten())

    features = np.hstack([hog_features, glcm_features, lbp_features])

    X_HED = images_to_HED(X)

    # Mean and variance for each channel
    for c in range(3):
        features = np.hstack([features,
            np.array([np.mean(X[..., c], axis=(1, 2)),   
            np.var(X[..., c], axis=(1, 2)),
            np.mean(X_HED[..., c], axis=(1, 2)),   
            np.var(X_HED[..., c], axis=(1, 2))]).T
        ])

    return features
    
# testing 
X_test_features = extract_features(X_test)
X_train_features = extract_features(X_train)
# Out:
# 100%|██████████| 2894/2894 [02:37<00:00, 18.38it/s]
# 100%|██████████| 7027/7027 [06:16<00:00, 18.65it/s]

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import make_pipeline

model = LinearRegression()
pipeline = make_pipeline(StandardScaler(), PCA(n_components=50), model)

def cross_validate_model(model, X, y, modelname):
    r2s = []
    mses = []
    i = 0
    kf = KFold(n_splits=5)
    for train, test in kf.split(X):
        X_train = X[train]
        X_test = X[test]

        y_train = y.iloc[train]
        y_test = y.iloc[test]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Compute scores
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)

        r2s.append(r2)
        mses.append(mse)
        print(f"Fold {i+1}: RMSE = {np.sqrt(mse):.4f}, R² = {r2:.4f}")

        if i == 0:
            plt.scatter(y_test, y_pred, s=4)

            # Fit line of best fit
            coeffs = np.polyfit(y_test, y_pred, 1)
            poly_eq = np.poly1d(coeffs)
            plt.plot(y_test, poly_eq(y_test), color="red", label="Best Fit Line")

            # Plot identity line (y = x)
            plt.plot(y_test, y_test, color="black", linestyle="--", alpha=0.5, label="Ideal Fit")

            # Add text with R² score
            plt.text(min(y_test), max(y_pred), f"RMSE = {np.sqrt(np.mean(mses)):.4f}", fontsize=12, ha="left", bbox=dict(facecolor="white", alpha=0.7))

            # Labels and title
            plt.xlabel("True CD11b")
            plt.ylabel("Predicted CD11b")
            plt.title(modelname+" True vs Predicted CD11b (First Fold)")
            plt.legend()
            plt.show()

        i += 1

    print(f"Overall: RMSE = {np.mean(np.sqrt(mses)):.4f}, R² = {np.mean(r2s):.4f}")

cross_validate_model(model, X_train_features, df_train['CD11b'], "Linear Regression")
# Out:
# Fold 1: RMSE = 1.8587, R² = -0.6471
# Fold 2: RMSE = 1.7709, R² = -0.9263
# Fold 3: RMSE = 1.7946, R² = -0.9875
# Fold 4: RMSE = 2.2948, R² = -1.1401
# Fold 5: RMSE = 2.1482, R² = -0.5974
# Overall: RMSE = 1.9734, R² = -0.8597

# %% [markdown]
# Now we'll train on all the data and test on the test data.

# %%
def plot_results(true_values, predictions, title="True Data vs Model Predictions"): 

    # Convert lists to numpy arrays
    predictions = np.array(predictions).flatten()  # Flatten to 1D
    true_values = np.array(true_values).flatten()  # Flatten to 1D

    # R2 Score
    r2 = r2_score(true_values, predictions)

    # RMSE (Root Mean Squared Error)
    rmse = np.sqrt(mean_squared_error(true_values, predictions))

    # Pearson correlation
    pearson_corr, _ = pearsonr(true_values, predictions)

    # Spearman correlation
    spearman_corr, _ = spearmanr(true_values, predictions)

    # Print the evaluation metrics
    print(f"R² Score: {r2:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"Pearson Correlation: {pearson_corr:.4f}")
    print(f"Spearman Correlation: {spearman_corr:.4f}")

    # Scatter plot: Predictions vs True Values
    plt.figure(figsize=(8, 6))
    plt.scatter(true_values, predictions, alpha=0.5, s=4)
    # Fit line of best fit
    coeffs = np.polyfit(true_values, predictions, 1)
    poly_eq = np.poly1d(coeffs)
    plt.plot(true_values, poly_eq(true_values), color="red", label="Best Fit Line")

    # Plot identity line (y = x)
    plt.plot(true_values, true_values, color="black", linestyle="--", alpha=0.5, label="Ideal Fit")

    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.title(title)
    plt.show()

    return [r2, rmse, pearson_corr, spearman_corr]

pipeline.fit(X_train_features, y_train)
y_preds = pipeline.predict(X_test_features)
results = plot_results(y_test, y_preds, title="OLS: True Data vs Model Predictions")

new_row = pd.DataFrame([["OLS"] + results], columns=results_df.columns)
results_df = pd.concat([results_df, new_row], ignore_index=True)
# Out:
# R² Score: -0.0086
# RMSE: 1.4423
# Pearson Correlation: 0.2620
# Spearman Correlation: 0.2560
# /tmp/dcs-tmp.u2101693/ipykernel_599956/2591634297.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)

# %% [markdown]
# ### <a id='toc2_2_2_'></a>[Random Forest](#toc0_)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

kf = KFold(n_splits=5)

rf = RandomForestRegressor(max_depth=20)
pipeline = make_pipeline(StandardScaler(), PCA(n_components=50), rf)

cross_validate_model(pipeline, X_train_features, df_train['CD11b'], "Random Forest Regressor")
# Out:
# Fold 1: RMSE = 1.5828, R² = -0.1944
# Fold 2: RMSE = 1.2075, R² = 0.1044
# Fold 3: RMSE = 1.1665, R² = 0.1604
# Fold 4: RMSE = 1.7235, R² = -0.2071
# Fold 5: RMSE = 1.6002, R² = 0.1136
# Overall: RMSE = 1.4561, R² = -0.0046

# %%
rf = RandomForestRegressor()

parameters = {'criterion': ["absolute_error",  "squared_error", "friedman_mse"], 'max_depth': [5, 10], 'n_estimators': [10, 25, 50]}
scoring = ['neg_root_mean_squared_error', 'r2']
clf = GridSearchCV(rf, parameters, cv=KFold(n_splits=5), refit=False, scoring=scoring, verbose=10)

num_components = 50

# We want to perform scaling and PCA in the pipeline so as to avoid data leakage during cross-validation
pipeline = make_pipeline(StandardScaler(), PCA(50), clf)
pipeline.fit(X_train_features, df_train['CD11b'])
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START criterion=absolute_error, max_depth=5, n_estimators=10.....
# [CV 1/5; 1/18] END criterion=absolute_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.664) r2: (test=-0.319) total time=  28.9s
# [CV 2/5; 1/18] START criterion=absolute_error, max_depth=5, n_estimators=10.....
# [CV 2/5; 1/18] END criterion=absolute_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.268) r2: (test=0.012) total time=  25.8s
# [CV 3/5; 1/18] START criterion=absolute_error, max_depth=5, n_estimators=10.....
# [CV 3/5; 1/18] END criterion=absolute_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.238) r2: (test=0.054) total time=  26.0s
# [CV 4/5; 1/18] START criterion=absolute_error, max_depth=5, n_estimators=10.....
# [CV 4/5; 1/18] END criterion=absolute_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.803) r2: (test=-0.321) total time=  25.5s
# [CV 5/5; 1/18] START criterion=absolute_error, max_depth=5, n_estimators=10.....
# [CV 5/5; 1/18] END criterion=absolute_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.614) r2: (test=0.098) total time=  28.8s
# [CV 1/5; 2/18] START criterion=absolute_error, max_depth=5, n_estimators=25.....
# [CV 1/5; 2/18] END criterion=absolute_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.599) r2: (test=-0.219) total time= 1.2min
# [CV 2/5; 2/18] START criterion=absolute_error, max_depth=5, n_estimators=25.....
# [CV 2/5; 2/18] END criterion=absolute_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.262) r2: (test=0.022) total time= 1.1min
# [CV 3/5; 2/18] START criterion=absolute_error, max_depth=5, n_estimators=25.....
# [CV 3/5; 2/18] END criterion=absolute_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.211) r2: (test=0.095) total time= 1.1min
# [CV 4/5; 2/18] START criterion=absolute_error, max_depth=5, n_estimators=25.....
# [CV 4/5; 2/18] END criterion=absolute_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.803) r2: (test=-0.321) total time= 1.1min
# [CV 5/5; 2/18] START criterion=absolute_error, max_depth=5, n_estimators=25.....
# [CV 5/5; 2/18] END criterion=absolute_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.570) r2: (test=0.147) total time= 1.2min
# [CV 1/5; 3/18] START criterion=absolute_error, max_depth=5, n_estimators=50.....
# [CV 1/5; 3/18] END criterion=absolute_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.606) r2: (test=-0.230) total time= 2.5min
# [CV 2/5; 3/18] START criterion=absolute_error, max_depth=5, n_estimators=50.....
# [CV 2/5; 3/18] END criterion=absolute_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.263) r2: (test=0.020) total time= 2.2min
# [CV 3/5; 3/18] START criterion=absolute_error, max_depth=5, n_estimators=50.....
# [CV 3/5; 3/18] END criterion=absolute_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.208) r2: (test=0.099) total time= 2.1min
# [CV 4/5; 3/18] START criterion=absolute_error, max_depth=5, n_estimators=50.....
# [CV 4/5; 3/18] END criterion=absolute_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.799) r2: (test=-0.315) total time= 2.1min
# [CV 5/5; 3/18] START criterion=absolute_error, max_depth=5, n_estimators=50.....
# [CV 5/5; 3/18] END criterion=absolute_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.583) r2: (test=0.132) total time= 2.4min
# [CV 1/5; 4/18] START criterion=absolute_error, max_depth=10, n_estimators=10....
# [CV 1/5; 4/18] END criterion=absolute_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.557) r2: (test=-0.156) total time=  36.8s
# [CV 2/5; 4/18] START criterion=absolute_error, max_depth=10, n_estimators=10....
# [CV 2/5; 4/18] END criterion=absolute_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.263) r2: (test=0.021) total time=  34.1s
# [CV 3/5; 4/18] START criterion=absolute_error, max_depth=10, n_estimators=10....
# [CV 3/5; 4/18] END criterion=absolute_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.238) r2: (test=0.054) total time=  31.0s
# [CV 4/5; 4/18] START criterion=absolute_error, max_depth=10, n_estimators=10....
# [CV 4/5; 4/18] END criterion=absolute_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.803) r2: (test=-0.321) total time=  32.0s
# [CV 5/5; 4/18] START criterion=absolute_error, max_depth=10, n_estimators=10....
# [CV 5/5; 4/18] END criterion=absolute_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.637) r2: (test=0.072) total time=  35.9s
# [CV 1/5; 5/18] START criterion=absolute_error, max_depth=10, n_estimators=25....
# [CV 1/5; 5/18] END criterion=absolute_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.542) r2: (test=-0.134) total time= 1.5min
# [CV 2/5; 5/18] START criterion=absolute_error, max_depth=10, n_estimators=25....
# [CV 2/5; 5/18] END criterion=absolute_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.232) r2: (test=0.067) total time= 1.4min
# [CV 3/5; 5/18] START criterion=absolute_error, max_depth=10, n_estimators=25....
# [CV 3/5; 5/18] END criterion=absolute_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.205) r2: (test=0.105) total time= 1.3min
# [CV 4/5; 5/18] START criterion=absolute_error, max_depth=10, n_estimators=25....
# [CV 4/5; 5/18] END criterion=absolute_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.774) r2: (test=-0.279) total time= 1.3min
# [CV 5/5; 5/18] START criterion=absolute_error, max_depth=10, n_estimators=25....
# [CV 5/5; 5/18] END criterion=absolute_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.632) r2: (test=0.078) total time= 1.4min
# [CV 1/5; 6/18] START criterion=absolute_error, max_depth=10, n_estimators=50....
# [CV 1/5; 6/18] END criterion=absolute_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.535) r2: (test=-0.123) total time= 3.0min
# [CV 2/5; 6/18] START criterion=absolute_error, max_depth=10, n_estimators=50....
# [CV 2/5; 6/18] END criterion=absolute_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.220) r2: (test=0.086) total time= 2.7min
# [CV 3/5; 6/18] START criterion=absolute_error, max_depth=10, n_estimators=50....
# [CV 3/5; 6/18] END criterion=absolute_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.210) r2: (test=0.097) total time= 2.5min
# [CV 4/5; 6/18] START criterion=absolute_error, max_depth=10, n_estimators=50....
# [CV 4/5; 6/18] END criterion=absolute_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.763) r2: (test=-0.263) total time= 2.6min
# [CV 5/5; 6/18] START criterion=absolute_error, max_depth=10, n_estimators=50....
# [CV 5/5; 6/18] END criterion=absolute_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.614) r2: (test=0.099) total time= 2.9min
# [CV 1/5; 7/18] START criterion=squared_error, max_depth=5, n_estimators=10......
# [CV 1/5; 7/18] END criterion=squared_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.533) r2: (test=-0.120) total time=   1.0s
# [CV 2/5; 7/18] START criterion=squared_error, max_depth=5, n_estimators=10......
# [CV 2/5; 7/18] END criterion=squared_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.197) r2: (test=0.119) total time=   1.0s
# [CV 3/5; 7/18] START criterion=squared_error, max_depth=5, n_estimators=10......
# [CV 3/5; 7/18] END criterion=squared_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.242) r2: (test=0.047) total time=   1.0s
# [CV 4/5; 7/18] START criterion=squared_error, max_depth=5, n_estimators=10......
# [CV 4/5; 7/18] END criterion=squared_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.700) r2: (test=-0.175) total time=   1.0s
# [CV 5/5; 7/18] START criterion=squared_error, max_depth=5, n_estimators=10......
# [CV 5/5; 7/18] END criterion=squared_error, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.589) r2: (test=0.126) total time=   1.0s
# [CV 1/5; 8/18] START criterion=squared_error, max_depth=5, n_estimators=25......
# [CV 1/5; 8/18] END criterion=squared_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.510) r2: (test=-0.087) total time=   2.5s
# [CV 2/5; 8/18] START criterion=squared_error, max_depth=5, n_estimators=25......
# [CV 2/5; 8/18] END criterion=squared_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.195) r2: (test=0.123) total time=   2.5s
# [CV 3/5; 8/18] START criterion=squared_error, max_depth=5, n_estimators=25......
# [CV 3/5; 8/18] END criterion=squared_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.246) r2: (test=0.043) total time=   2.5s
# [CV 4/5; 8/18] START criterion=squared_error, max_depth=5, n_estimators=25......
# [CV 4/5; 8/18] END criterion=squared_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.702) r2: (test=-0.178) total time=   2.5s
# [CV 5/5; 8/18] START criterion=squared_error, max_depth=5, n_estimators=25......
# [CV 5/5; 8/18] END criterion=squared_error, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.551) r2: (test=0.167) total time=   2.5s
# [CV 1/5; 9/18] START criterion=squared_error, max_depth=5, n_estimators=50......
# [CV 1/5; 9/18] END criterion=squared_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.514) r2: (test=-0.093) total time=   5.1s
# [CV 2/5; 9/18] START criterion=squared_error, max_depth=5, n_estimators=50......
# [CV 2/5; 9/18] END criterion=squared_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.189) r2: (test=0.131) total time=   5.0s
# [CV 3/5; 9/18] START criterion=squared_error, max_depth=5, n_estimators=50......
# [CV 3/5; 9/18] END criterion=squared_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.247) r2: (test=0.040) total time=   5.0s
# [CV 4/5; 9/18] START criterion=squared_error, max_depth=5, n_estimators=50......
# [CV 4/5; 9/18] END criterion=squared_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.717) r2: (test=-0.198) total time=   5.0s
# [CV 5/5; 9/18] START criterion=squared_error, max_depth=5, n_estimators=50......
# [CV 5/5; 9/18] END criterion=squared_error, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.557) r2: (test=0.161) total time=   5.1s
# [CV 1/5; 10/18] START criterion=squared_error, max_depth=10, n_estimators=10....
# [CV 1/5; 10/18] END criterion=squared_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.575) r2: (test=-0.183) total time=   1.9s
# [CV 2/5; 10/18] START criterion=squared_error, max_depth=10, n_estimators=10....
# [CV 2/5; 10/18] END criterion=squared_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.225) r2: (test=0.078) total time=   1.9s
# [CV 3/5; 10/18] START criterion=squared_error, max_depth=10, n_estimators=10....
# [CV 3/5; 10/18] END criterion=squared_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.266) r2: (test=0.011) total time=   1.9s
# [CV 4/5; 10/18] START criterion=squared_error, max_depth=10, n_estimators=10....
# [CV 4/5; 10/18] END criterion=squared_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.728) r2: (test=-0.213) total time=   1.8s
# [CV 5/5; 10/18] START criterion=squared_error, max_depth=10, n_estimators=10....
# [CV 5/5; 10/18] END criterion=squared_error, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.635) r2: (test=0.074) total time=   1.9s
# [CV 1/5; 11/18] START criterion=squared_error, max_depth=10, n_estimators=25....
# [CV 1/5; 11/18] END criterion=squared_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.531) r2: (test=-0.117) total time=   4.7s
# [CV 2/5; 11/18] START criterion=squared_error, max_depth=10, n_estimators=25....
# [CV 2/5; 11/18] END criterion=squared_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.212) r2: (test=0.097) total time=   4.6s
# [CV 3/5; 11/18] START criterion=squared_error, max_depth=10, n_estimators=25....
# [CV 3/5; 11/18] END criterion=squared_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.248) r2: (test=0.040) total time=   4.6s
# [CV 4/5; 11/18] START criterion=squared_error, max_depth=10, n_estimators=25....
# [CV 4/5; 11/18] END criterion=squared_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.702) r2: (test=-0.177) total time=   4.6s
# [CV 5/5; 11/18] START criterion=squared_error, max_depth=10, n_estimators=25....
# [CV 5/5; 11/18] END criterion=squared_error, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.626) r2: (test=0.085) total time=   4.7s
# [CV 1/5; 12/18] START criterion=squared_error, max_depth=10, n_estimators=50....
# [CV 1/5; 12/18] END criterion=squared_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.532) r2: (test=-0.119) total time=   9.3s
# [CV 2/5; 12/18] START criterion=squared_error, max_depth=10, n_estimators=50....
# [CV 2/5; 12/18] END criterion=squared_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.197) r2: (test=0.120) total time=   9.3s
# [CV 3/5; 12/18] START criterion=squared_error, max_depth=10, n_estimators=50....
# [CV 3/5; 12/18] END criterion=squared_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.237) r2: (test=0.056) total time=   9.2s
# [CV 4/5; 12/18] START criterion=squared_error, max_depth=10, n_estimators=50....
# [CV 4/5; 12/18] END criterion=squared_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.717) r2: (test=-0.199) total time=   9.2s
# [CV 5/5; 12/18] START criterion=squared_error, max_depth=10, n_estimators=50....
# [CV 5/5; 12/18] END criterion=squared_error, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.582) r2: (test=0.134) total time=   9.3s
# [CV 1/5; 13/18] START criterion=friedman_mse, max_depth=5, n_estimators=10......
# [CV 1/5; 13/18] END criterion=friedman_mse, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.525) r2: (test=-0.109) total time=   1.0s
# [CV 2/5; 13/18] START criterion=friedman_mse, max_depth=5, n_estimators=10......
# [CV 2/5; 13/18] END criterion=friedman_mse, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.202) r2: (test=0.112) total time=   1.0s
# [CV 3/5; 13/18] START criterion=friedman_mse, max_depth=5, n_estimators=10......
# [CV 3/5; 13/18] END criterion=friedman_mse, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.241) r2: (test=0.049) total time=   1.0s
# [CV 4/5; 13/18] START criterion=friedman_mse, max_depth=5, n_estimators=10......
# [CV 4/5; 13/18] END criterion=friedman_mse, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.704) r2: (test=-0.180) total time=   1.0s
# [CV 5/5; 13/18] START criterion=friedman_mse, max_depth=5, n_estimators=10......
# [CV 5/5; 13/18] END criterion=friedman_mse, max_depth=5, n_estimators=10; neg_root_mean_squared_error: (test=-1.571) r2: (test=0.146) total time=   1.0s
# [CV 1/5; 14/18] START criterion=friedman_mse, max_depth=5, n_estimators=25......
# [CV 1/5; 14/18] END criterion=friedman_mse, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.527) r2: (test=-0.112) total time=   2.5s
# [CV 2/5; 14/18] START criterion=friedman_mse, max_depth=5, n_estimators=25......
# [CV 2/5; 14/18] END criterion=friedman_mse, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.188) r2: (test=0.133) total time=   2.5s
# [CV 3/5; 14/18] START criterion=friedman_mse, max_depth=5, n_estimators=25......
# [CV 3/5; 14/18] END criterion=friedman_mse, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.233) r2: (test=0.063) total time=   2.5s
# [CV 4/5; 14/18] START criterion=friedman_mse, max_depth=5, n_estimators=25......
# [CV 4/5; 14/18] END criterion=friedman_mse, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.703) r2: (test=-0.179) total time=   2.5s
# [CV 5/5; 14/18] START criterion=friedman_mse, max_depth=5, n_estimators=25......
# [CV 5/5; 14/18] END criterion=friedman_mse, max_depth=5, n_estimators=25; neg_root_mean_squared_error: (test=-1.570) r2: (test=0.147) total time=   2.5s
# [CV 1/5; 15/18] START criterion=friedman_mse, max_depth=5, n_estimators=50......
# [CV 1/5; 15/18] END criterion=friedman_mse, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.515) r2: (test=-0.095) total time=   5.1s
# [CV 2/5; 15/18] START criterion=friedman_mse, max_depth=5, n_estimators=50......
# [CV 2/5; 15/18] END criterion=friedman_mse, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.191) r2: (test=0.129) total time=   5.0s
# [CV 3/5; 15/18] START criterion=friedman_mse, max_depth=5, n_estimators=50......
# [CV 3/5; 15/18] END criterion=friedman_mse, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.245) r2: (test=0.043) total time=   5.0s
# [CV 4/5; 15/18] START criterion=friedman_mse, max_depth=5, n_estimators=50......
# [CV 4/5; 15/18] END criterion=friedman_mse, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.705) r2: (test=-0.182) total time=   5.0s
# [CV 5/5; 15/18] START criterion=friedman_mse, max_depth=5, n_estimators=50......
# [CV 5/5; 15/18] END criterion=friedman_mse, max_depth=5, n_estimators=50; neg_root_mean_squared_error: (test=-1.564) r2: (test=0.154) total time=   5.0s
# [CV 1/5; 16/18] START criterion=friedman_mse, max_depth=10, n_estimators=10.....
# [CV 1/5; 16/18] END criterion=friedman_mse, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.560) r2: (test=-0.160) total time=   1.9s
# [CV 2/5; 16/18] START criterion=friedman_mse, max_depth=10, n_estimators=10.....
# [CV 2/5; 16/18] END criterion=friedman_mse, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.222) r2: (test=0.083) total time=   1.9s
# [CV 3/5; 16/18] START criterion=friedman_mse, max_depth=10, n_estimators=10.....
# [CV 3/5; 16/18] END criterion=friedman_mse, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.270) r2: (test=0.005) total time=   1.9s
# [CV 4/5; 16/18] START criterion=friedman_mse, max_depth=10, n_estimators=10.....
# [CV 4/5; 16/18] END criterion=friedman_mse, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.721) r2: (test=-0.203) total time=   1.8s
# [CV 5/5; 16/18] START criterion=friedman_mse, max_depth=10, n_estimators=10.....
# [CV 5/5; 16/18] END criterion=friedman_mse, max_depth=10, n_estimators=10; neg_root_mean_squared_error: (test=-1.628) r2: (test=0.083) total time=   1.9s
# [CV 1/5; 17/18] START criterion=friedman_mse, max_depth=10, n_estimators=25.....
# [CV 1/5; 17/18] END criterion=friedman_mse, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.510) r2: (test=-0.087) total time=   4.7s
# [CV 2/5; 17/18] START criterion=friedman_mse, max_depth=10, n_estimators=25.....
# [CV 2/5; 17/18] END criterion=friedman_mse, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.211) r2: (test=0.100) total time=   4.7s
# [CV 3/5; 17/18] START criterion=friedman_mse, max_depth=10, n_estimators=25.....
# [CV 3/5; 17/18] END criterion=friedman_mse, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.259) r2: (test=0.022) total time=   4.7s
# [CV 4/5; 17/18] START criterion=friedman_mse, max_depth=10, n_estimators=25.....
# [CV 4/5; 17/18] END criterion=friedman_mse, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.708) r2: (test=-0.185) total time=   4.6s
# [CV 5/5; 17/18] START criterion=friedman_mse, max_depth=10, n_estimators=25.....
# [CV 5/5; 17/18] END criterion=friedman_mse, max_depth=10, n_estimators=25; neg_root_mean_squared_error: (test=-1.604) r2: (test=0.110) total time=   4.7s
# [CV 1/5; 18/18] START criterion=friedman_mse, max_depth=10, n_estimators=50.....
# [CV 1/5; 18/18] END criterion=friedman_mse, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.506) r2: (test=-0.082) total time=   9.4s
# [CV 2/5; 18/18] START criterion=friedman_mse, max_depth=10, n_estimators=50.....
# [CV 2/5; 18/18] END criterion=friedman_mse, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.203) r2: (test=0.111) total time=   9.3s
# [CV 3/5; 18/18] START criterion=friedman_mse, max_depth=10, n_estimators=50.....
# [CV 3/5; 18/18] END criterion=friedman_mse, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.242) r2: (test=0.048) total time=   9.3s
# [CV 4/5; 18/18] START criterion=friedman_mse, max_depth=10, n_estimators=50.....
# [CV 4/5; 18/18] END criterion=friedman_mse, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.695) r2: (test=-0.168) total time=   9.2s
# [CV 5/5; 18/18] START criterion=friedman_mse, max_depth=10, n_estimators=50.....
# [CV 5/5; 18/18] END criterion=friedman_mse, max_depth=10, n_estimators=50; neg_root_mean_squared_error: (test=-1.582) r2: (test=0.134) total time=   9.4s
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('pca', PCA(n_components=50)),
#                 ('gridsearchcv',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                               estimator=RandomForestRegressor(),
#                               param_grid={'criterion': ['absolute_error',
#                                                         'squared_error',
#                                                         'friedman_mse'],
#                                           'max_depth': [5, 10],
#                                           'n_estimators': [10, 25, 50]},
#                               refit=False,
#                               scoring=['neg_root_mean_squared_error', 'r2'],
#                               verbose=10))])

# %%
# Get table of parameters
params = [[params['criterion'], params['max_depth'], params['n_estimators']] for params in clf.cv_results_['params']] 

keys = ['mean_test_neg_root_mean_squared_error', 'std_test_neg_root_mean_squared_error', 'mean_test_r2', 'std_test_r2']

# Get table of results
results = np.array([clf.cv_results_.get(key) for key in keys])

# Format the metrics for the table and create columns
keys = [key.replace('test_', '').replace('_', ' ') for key in keys]
columns = ['criterion', 'max_depth', 'n_estimators'] + keys

# Create the final table and dataframe
table = np.hstack([params, results.T])
df = pd.DataFrame(table, columns=columns)
df[keys] = df[keys].astype(float).round(3)
df.iloc[df[['mean neg root mean squared error', 'mean r2']].idxmax()]
# Out:
#        criterion max_depth n_estimators  mean neg root mean squared error  \
# 7  squared_error         5           25                            -1.441
# 7  squared_error         5           25                            -1.441
#
#    std neg root mean squared error  mean r2  std r2
# 7                            0.192    0.014   0.129
# 7                            0.192    0.014   0.129

# %% [markdown]
# The best results come from a maximum depth of 5 and the number of estimators of 25.

# %%
rf = RandomForestRegressor(criterion="squared_error", max_depth=5, n_estimators=25)
pipeline = make_pipeline(StandardScaler(), PCA(50), rf)
pipeline.fit(X_train_features, y_train)
y_preds = pipeline.predict(X_test_features)
results = plot_results(y_test, y_preds, title="RandomForestRegressor: True Data vs Model Predictions")

new_row = pd.DataFrame([["RandomForest"] + results], columns=results_df.columns)
results_df = pd.concat([results_df, new_row], ignore_index=True)
# Out:
# R² Score: -0.0336
# RMSE: 1.4601
# Pearson Correlation: 0.2263
# Spearman Correlation: 0.2059

# %%
results_df
# Out:
#           model        r2      RMSE   Pearson  Spearman
# 0           OLS -0.008557  1.442298  0.262029  0.255963
# 1  RandomForest -0.033607  1.460099  0.226290  0.205908

# %% [markdown]
# ### <a id='toc2_2_3_'></a>[SVC](#toc0_)

# %%
from sklearn.model_selection import KFold
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

kf = KFold(n_splits=5)

svr = SVR(kernel='rbf', C=0.1)
pipeline = make_pipeline(StandardScaler(), PCA(n_components=50), svr)

cross_validate_model(pipeline, X_train_features, y_train, "SVR")
# Out:
# Fold 1: RMSE = 1.5206, R² = -0.1024
# Fold 2: RMSE = 1.3393, R² = -0.1017
# Fold 3: RMSE = 1.2373, R² = 0.0552
# Fold 4: RMSE = 1.9838, R² = -0.5993
# Fold 5: RMSE = 1.7321, R² = -0.0385
# Overall: RMSE = 1.5626, R² = -0.1573

# %%
parameters = {'kernel': ['rbf', 'poly'], 'C': np.logspace(-1, 2, 10), 'gamma': np.logspace(-4, -1, 10)}
scoring = ['neg_root_mean_squared_error', 'r2']
svr = SVR()
clf = GridSearchCV(svr, parameters, cv=KFold(n_splits=5), refit=False, scoring=scoring, verbose=10)

num_components = 50

# We want to perform scaling and PCA in the pipeline so as to avoid data leakage during cross-validation
pipeline = make_pipeline(StandardScaler(), PCA(n_components=num_components), clf)
pipeline.fit(X_train_features, y_train)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV 1/5; 1/200] START C=0.1, gamma=0.0001, kernel=rbf...........................
# [CV 1/5; 1/200] END C=0.1, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.378) r2: (test=0.095) total time=   1.6s
# [CV 2/5; 1/200] START C=0.1, gamma=0.0001, kernel=rbf...........................
# [CV 2/5; 1/200] END C=0.1, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.224) r2: (test=0.080) total time=   1.5s
# [CV 3/5; 1/200] START C=0.1, gamma=0.0001, kernel=rbf...........................
# [CV 3/5; 1/200] END C=0.1, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.181) r2: (test=0.139) total time=   1.5s
# [CV 4/5; 1/200] START C=0.1, gamma=0.0001, kernel=rbf...........................
# [CV 4/5; 1/200] END C=0.1, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.813) r2: (test=-0.336) total time=   1.4s
# [CV 5/5; 1/200] START C=0.1, gamma=0.0001, kernel=rbf...........................
# [CV 5/5; 1/200] END C=0.1, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.681) r2: (test=0.021) total time=   1.4s
# [CV 1/5; 2/200] START C=0.1, gamma=0.0001, kernel=poly..........................
# [CV 1/5; 2/200] END C=0.1, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.546) r2: (test=-0.139) total time=   1.2s
# [CV 2/5; 2/200] START C=0.1, gamma=0.0001, kernel=poly..........................
# [CV 2/5; 2/200] END C=0.1, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.289) r2: (test=-0.021) total time=   1.0s
# [CV 3/5; 2/200] START C=0.1, gamma=0.0001, kernel=poly..........................
# [CV 3/5; 2/200] END C=0.1, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.279) r2: (test=-0.010) total time=   1.1s
# [CV 4/5; 2/200] START C=0.1, gamma=0.0001, kernel=poly..........................
# [CV 4/5; 2/200] END C=0.1, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.692) r2: (test=-0.163) total time=   1.2s
# [CV 5/5; 2/200] START C=0.1, gamma=0.0001, kernel=poly..........................
# [CV 5/5; 2/200] END C=0.1, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.838) r2: (test=-0.169) total time=   1.1s
# [CV 1/5; 3/200] START C=0.1, gamma=0.00021544346900318845, kernel=rbf...........
# [CV 1/5; 3/200] END C=0.1, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.393) r2: (test=0.074) total time=   1.5s
# [CV 2/5; 3/200] START C=0.1, gamma=0.00021544346900318845, kernel=rbf...........
# [CV 2/5; 3/200] END C=0.1, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.233) r2: (test=0.067) total time=   1.4s
# [CV 3/5; 3/200] START C=0.1, gamma=0.00021544346900318845, kernel=rbf...........
# [CV 3/5; 3/200] END C=0.1, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.184) r2: (test=0.135) total time=   1.4s
# [CV 4/5; 3/200] START C=0.1, gamma=0.00021544346900318845, kernel=rbf...........
# [CV 4/5; 3/200] END C=0.1, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.842) r2: (test=-0.380) total time=   1.4s
# [CV 5/5; 3/200] START C=0.1, gamma=0.00021544346900318845, kernel=rbf...........
# [CV 5/5; 3/200] END C=0.1, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.682) r2: (test=0.021) total time=   1.4s
# [CV 1/5; 4/200] START C=0.1, gamma=0.00021544346900318845, kernel=poly..........
# [CV 1/5; 4/200] END C=0.1, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.515) r2: (test=-0.094) total time=   1.1s
# [CV 2/5; 4/200] START C=0.1, gamma=0.00021544346900318845, kernel=poly..........
# [CV 2/5; 4/200] END C=0.1, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.279) r2: (test=-0.005) total time=   1.2s
# [CV 3/5; 4/200] START C=0.1, gamma=0.00021544346900318845, kernel=poly..........
# [CV 3/5; 4/200] END C=0.1, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.268) r2: (test=0.007) total time=   1.1s
# [CV 4/5; 4/200] START C=0.1, gamma=0.00021544346900318845, kernel=poly..........
# [CV 4/5; 4/200] END C=0.1, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.683) r2: (test=-0.151) total time=   1.1s
# [CV 5/5; 4/200] START C=0.1, gamma=0.00021544346900318845, kernel=poly..........
# [CV 5/5; 4/200] END C=0.1, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.790) r2: (test=-0.109) total time=   1.0s
# [CV 1/5; 5/200] START C=0.1, gamma=0.00046415888336127773, kernel=rbf...........
# [CV 1/5; 5/200] END C=0.1, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.424) r2: (test=0.034) total time=   1.4s
# [CV 2/5; 5/200] START C=0.1, gamma=0.00046415888336127773, kernel=rbf...........
# [CV 2/5; 5/200] END C=0.1, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.243) r2: (test=0.051) total time=   1.5s
# [CV 3/5; 5/200] START C=0.1, gamma=0.00046415888336127773, kernel=rbf...........
# [CV 3/5; 5/200] END C=0.1, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.198) r2: (test=0.114) total time=   1.4s
# [CV 4/5; 5/200] START C=0.1, gamma=0.00046415888336127773, kernel=rbf...........
# [CV 4/5; 5/200] END C=0.1, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.863) r2: (test=-0.410) total time=   1.4s
# [CV 5/5; 5/200] START C=0.1, gamma=0.00046415888336127773, kernel=rbf...........
# [CV 5/5; 5/200] END C=0.1, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.684) r2: (test=0.019) total time=   1.6s
# [CV 1/5; 6/200] START C=0.1, gamma=0.00046415888336127773, kernel=poly..........
# [CV 1/5; 6/200] END C=0.1, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.469) r2: (test=-0.029) total time=   1.1s
# [CV 2/5; 6/200] START C=0.1, gamma=0.00046415888336127773, kernel=poly..........
# [CV 2/5; 6/200] END C=0.1, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.268) r2: (test=0.013) total time=   1.1s
# [CV 3/5; 6/200] START C=0.1, gamma=0.00046415888336127773, kernel=poly..........
# [CV 3/5; 6/200] END C=0.1, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.240) r2: (test=0.052) total time=   1.1s
# [CV 4/5; 6/200] START C=0.1, gamma=0.00046415888336127773, kernel=poly..........
# [CV 4/5; 6/200] END C=0.1, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.699) r2: (test=-0.172) total time=   1.0s
# [CV 5/5; 6/200] START C=0.1, gamma=0.00046415888336127773, kernel=poly..........
# [CV 5/5; 6/200] END C=0.1, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.645) r2: (test=0.063) total time=   1.0s
# [CV 1/5; 7/200] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 1/5; 7/200] END C=0.1, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.449) r2: (test=-0.001) total time=   1.4s
# [CV 2/5; 7/200] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 2/5; 7/200] END C=0.1, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.239) r2: (test=0.057) total time=   1.4s
# [CV 3/5; 7/200] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 3/5; 7/200] END C=0.1, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.216) r2: (test=0.087) total time=   1.5s
# [CV 4/5; 7/200] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 4/5; 7/200] END C=0.1, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.882) r2: (test=-0.440) total time=   1.5s
# [CV 5/5; 7/200] START C=0.1, gamma=0.001, kernel=rbf............................
# [CV 5/5; 7/200] END C=0.1, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.727) r2: (test=-0.033) total time=   1.5s
# [CV 1/5; 8/200] START C=0.1, gamma=0.001, kernel=poly...........................
# [CV 1/5; 8/200] END C=0.1, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.458) r2: (test=-0.013) total time=   1.1s
# [CV 2/5; 8/200] START C=0.1, gamma=0.001, kernel=poly...........................
# [CV 2/5; 8/200] END C=0.1, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.284) r2: (test=-0.013) total time=   1.1s
# [CV 3/5; 8/200] START C=0.1, gamma=0.001, kernel=poly...........................
# [CV 3/5; 8/200] END C=0.1, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.315) r2: (test=-0.068) total time=   1.1s
# [CV 4/5; 8/200] START C=0.1, gamma=0.001, kernel=poly...........................
# [CV 4/5; 8/200] END C=0.1, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.755) r2: (test=-0.252) total time=   1.1s
# [CV 5/5; 8/200] START C=0.1, gamma=0.001, kernel=poly...........................
# [CV 5/5; 8/200] END C=0.1, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.685) r2: (test=0.018) total time=   1.0s
# [CV 1/5; 9/200] START C=0.1, gamma=0.002154434690031882, kernel=rbf.............
# [CV 1/5; 9/200] END C=0.1, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.454) r2: (test=-0.009) total time=   1.4s
# [CV 2/5; 9/200] START C=0.1, gamma=0.002154434690031882, kernel=rbf.............
# [CV 2/5; 9/200] END C=0.1, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.222) r2: (test=0.083) total time=   1.6s
# [CV 3/5; 9/200] START C=0.1, gamma=0.002154434690031882, kernel=rbf.............
# [CV 3/5; 9/200] END C=0.1, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.218) r2: (test=0.084) total time=   1.5s
# [CV 4/5; 9/200] START C=0.1, gamma=0.002154434690031882, kernel=rbf.............
# [CV 4/5; 9/200] END C=0.1, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.861) r2: (test=-0.408) total time=   1.4s
# [CV 5/5; 9/200] START C=0.1, gamma=0.002154434690031882, kernel=rbf.............
# [CV 5/5; 9/200] END C=0.1, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.784) r2: (test=-0.102) total time=   1.4s
# [CV 1/5; 10/200] START C=0.1, gamma=0.002154434690031882, kernel=poly...........
# [CV 1/5; 10/200] END C=0.1, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-1.521) r2: (test=-0.102) total time=   1.5s
# [CV 2/5; 10/200] START C=0.1, gamma=0.002154434690031882, kernel=poly...........
# [CV 2/5; 10/200] END C=0.1, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-1.328) r2: (test=-0.083) total time=   1.4s
# [CV 3/5; 10/200] START C=0.1, gamma=0.002154434690031882, kernel=poly...........
# [CV 3/5; 10/200] END C=0.1, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-1.622) r2: (test=-0.623) total time=   1.4s
# [CV 4/5; 10/200] START C=0.1, gamma=0.002154434690031882, kernel=poly...........
# [CV 4/5; 10/200] END C=0.1, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-1.805) r2: (test=-0.324) total time=   1.5s
# [CV 5/5; 10/200] START C=0.1, gamma=0.002154434690031882, kernel=poly...........
# [CV 5/5; 10/200] END C=0.1, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-1.898) r2: (test=-0.247) total time=   1.5s
# [CV 1/5; 11/200] START C=0.1, gamma=0.004641588833612777, kernel=rbf............
# [CV 1/5; 11/200] END C=0.1, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.493) r2: (test=-0.062) total time=   1.4s
# [CV 2/5; 11/200] START C=0.1, gamma=0.004641588833612777, kernel=rbf............
# [CV 2/5; 11/200] END C=0.1, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.249) r2: (test=0.042) total time=   1.4s
# [CV 3/5; 11/200] START C=0.1, gamma=0.004641588833612777, kernel=rbf............
# [CV 3/5; 11/200] END C=0.1, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.249) r2: (test=0.037) total time=   1.5s
# [CV 4/5; 11/200] START C=0.1, gamma=0.004641588833612777, kernel=rbf............
# [CV 4/5; 11/200] END C=0.1, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.771) r2: (test=-0.274) total time=   1.5s
# [CV 5/5; 11/200] START C=0.1, gamma=0.004641588833612777, kernel=rbf............
# [CV 5/5; 11/200] END C=0.1, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.808) r2: (test=-0.132) total time=   1.4s
# [CV 1/5; 12/200] START C=0.1, gamma=0.004641588833612777, kernel=poly...........
# [CV 1/5; 12/200] END C=0.1, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-2.169) r2: (test=-1.244) total time=   4.8s
# [CV 2/5; 12/200] START C=0.1, gamma=0.004641588833612777, kernel=poly...........
# [CV 2/5; 12/200] END C=0.1, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-1.718) r2: (test=-0.812) total time=   4.6s
# [CV 3/5; 12/200] START C=0.1, gamma=0.004641588833612777, kernel=poly...........
# [CV 3/5; 12/200] END C=0.1, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-1.941) r2: (test=-1.326) total time=   4.2s
# [CV 4/5; 12/200] START C=0.1, gamma=0.004641588833612777, kernel=poly...........
# [CV 4/5; 12/200] END C=0.1, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-2.185) r2: (test=-0.940) total time=   5.0s
# [CV 5/5; 12/200] START C=0.1, gamma=0.004641588833612777, kernel=poly...........
# [CV 5/5; 12/200] END C=0.1, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-3.247) r2: (test=-2.649) total time=   3.4s
# [CV 1/5; 13/200] START C=0.1, gamma=0.01, kernel=rbf............................
# [CV 1/5; 13/200] END C=0.1, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.546) r2: (test=-0.140) total time=   1.4s
# [CV 2/5; 13/200] START C=0.1, gamma=0.01, kernel=rbf............................
# [CV 2/5; 13/200] END C=0.1, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.288) r2: (test=-0.019) total time=   2.1s
# [CV 3/5; 13/200] START C=0.1, gamma=0.01, kernel=rbf............................
# [CV 3/5; 13/200] END C=0.1, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.280) r2: (test=-0.012) total time=   1.6s
# [CV 4/5; 13/200] START C=0.1, gamma=0.01, kernel=rbf............................
# [CV 4/5; 13/200] END C=0.1, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.698) r2: (test=-0.171) total time=   1.5s
# [CV 5/5; 13/200] START C=0.1, gamma=0.01, kernel=rbf............................
# [CV 5/5; 13/200] END C=0.1, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.842) r2: (test=-0.174) total time=   1.5s
# [CV 1/5; 14/200] START C=0.1, gamma=0.01, kernel=poly...........................
# [CV 1/5; 14/200] END C=0.1, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-3.622) r2: (test=-5.253) total time=  11.0s
# [CV 2/5; 14/200] START C=0.1, gamma=0.01, kernel=poly...........................
# [CV 2/5; 14/200] END C=0.1, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-2.662) r2: (test=-3.352) total time=  11.0s
# [CV 3/5; 14/200] START C=0.1, gamma=0.01, kernel=poly...........................
# [CV 3/5; 14/200] END C=0.1, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-3.345) r2: (test=-5.906) total time=   9.8s
# [CV 4/5; 14/200] START C=0.1, gamma=0.01, kernel=poly...........................
# [CV 4/5; 14/200] END C=0.1, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-2.822) r2: (test=-2.236) total time=  10.0s
# [CV 5/5; 14/200] START C=0.1, gamma=0.01, kernel=poly...........................
# [CV 5/5; 14/200] END C=0.1, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-5.475) r2: (test=-9.377) total time=   7.8s
# [CV 1/5; 15/200] START C=0.1, gamma=0.021544346900318822, kernel=rbf............
# [CV 1/5; 15/200] END C=0.1, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.548) r2: (test=-0.143) total time=   1.6s
# [CV 2/5; 15/200] START C=0.1, gamma=0.021544346900318822, kernel=rbf............
# [CV 2/5; 15/200] END C=0.1, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.289) r2: (test=-0.021) total time=   1.6s
# [CV 3/5; 15/200] START C=0.1, gamma=0.021544346900318822, kernel=rbf............
# [CV 3/5; 15/200] END C=0.1, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.281) r2: (test=-0.013) total time=   1.6s
# [CV 4/5; 15/200] START C=0.1, gamma=0.021544346900318822, kernel=rbf............
# [CV 4/5; 15/200] END C=0.1, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.694) r2: (test=-0.166) total time=   1.6s
# [CV 5/5; 15/200] START C=0.1, gamma=0.021544346900318822, kernel=rbf............
# [CV 5/5; 15/200] END C=0.1, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.843) r2: (test=-0.176) total time=   1.5s
# [CV 1/5; 16/200] START C=0.1, gamma=0.021544346900318822, kernel=poly...........
# [CV 1/5; 16/200] END C=0.1, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.3s
# [CV 2/5; 16/200] START C=0.1, gamma=0.021544346900318822, kernel=poly...........
# [CV 2/5; 16/200] END C=0.1, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.4s
# [CV 3/5; 16/200] START C=0.1, gamma=0.021544346900318822, kernel=poly...........
# [CV 3/5; 16/200] END C=0.1, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   8.8s
# [CV 4/5; 16/200] START C=0.1, gamma=0.021544346900318822, kernel=poly...........
# [CV 4/5; 16/200] END C=0.1, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=  10.3s
# [CV 5/5; 16/200] START C=0.1, gamma=0.021544346900318822, kernel=poly...........
# [CV 5/5; 16/200] END C=0.1, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.7s
# [CV 1/5; 17/200] START C=0.1, gamma=0.046415888336127774, kernel=rbf............
# [CV 1/5; 17/200] END C=0.1, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.548) r2: (test=-0.143) total time=   2.0s
# [CV 2/5; 17/200] START C=0.1, gamma=0.046415888336127774, kernel=rbf............
# [CV 2/5; 17/200] END C=0.1, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.289) r2: (test=-0.021) total time=   2.2s
# [CV 3/5; 17/200] START C=0.1, gamma=0.046415888336127774, kernel=rbf............
# [CV 3/5; 17/200] END C=0.1, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.281) r2: (test=-0.013) total time=   2.1s
# [CV 4/5; 17/200] START C=0.1, gamma=0.046415888336127774, kernel=rbf............
# [CV 4/5; 17/200] END C=0.1, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.694) r2: (test=-0.166) total time=   2.0s
# [CV 5/5; 17/200] START C=0.1, gamma=0.046415888336127774, kernel=rbf............
# [CV 5/5; 17/200] END C=0.1, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.843) r2: (test=-0.176) total time=   1.9s
# [CV 1/5; 18/200] START C=0.1, gamma=0.046415888336127774, kernel=poly...........
# [CV 1/5; 18/200] END C=0.1, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.1s
# [CV 2/5; 18/200] START C=0.1, gamma=0.046415888336127774, kernel=poly...........
# [CV 2/5; 18/200] END C=0.1, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.2s
# [CV 3/5; 18/200] START C=0.1, gamma=0.046415888336127774, kernel=poly...........
# [CV 3/5; 18/200] END C=0.1, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   9.1s
# [CV 4/5; 18/200] START C=0.1, gamma=0.046415888336127774, kernel=poly...........
# [CV 4/5; 18/200] END C=0.1, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=   9.6s
# [CV 5/5; 18/200] START C=0.1, gamma=0.046415888336127774, kernel=poly...........
# [CV 5/5; 18/200] END C=0.1, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.3s
# [CV 1/5; 19/200] START C=0.1, gamma=0.1, kernel=rbf.............................
# [CV 1/5; 19/200] END C=0.1, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.548) r2: (test=-0.143) total time=   1.8s
# [CV 2/5; 19/200] START C=0.1, gamma=0.1, kernel=rbf.............................
# [CV 2/5; 19/200] END C=0.1, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.289) r2: (test=-0.021) total time=   1.8s
# [CV 3/5; 19/200] START C=0.1, gamma=0.1, kernel=rbf.............................
# [CV 3/5; 19/200] END C=0.1, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.281) r2: (test=-0.013) total time=   1.7s
# [CV 4/5; 19/200] START C=0.1, gamma=0.1, kernel=rbf.............................
# [CV 4/5; 19/200] END C=0.1, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.694) r2: (test=-0.166) total time=   1.9s
# [CV 5/5; 19/200] START C=0.1, gamma=0.1, kernel=rbf.............................
# [CV 5/5; 19/200] END C=0.1, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.843) r2: (test=-0.176) total time=   2.1s
# [CV 1/5; 20/200] START C=0.1, gamma=0.1, kernel=poly............................
# [CV 1/5; 20/200] END C=0.1, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.1s
# [CV 2/5; 20/200] START C=0.1, gamma=0.1, kernel=poly............................
# [CV 2/5; 20/200] END C=0.1, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.5s
# [CV 3/5; 20/200] START C=0.1, gamma=0.1, kernel=poly............................
# [CV 3/5; 20/200] END C=0.1, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   9.0s
# [CV 4/5; 20/200] START C=0.1, gamma=0.1, kernel=poly............................
# [CV 4/5; 20/200] END C=0.1, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=  10.3s
# [CV 5/5; 20/200] START C=0.1, gamma=0.1, kernel=poly............................
# [CV 5/5; 20/200] END C=0.1, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.1s
# [CV 1/5; 21/200] START C=0.21544346900318834, gamma=0.0001, kernel=rbf..........
# [CV 1/5; 21/200] END C=0.21544346900318834, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.380) r2: (test=0.092) total time=   1.6s
# [CV 2/5; 21/200] START C=0.21544346900318834, gamma=0.0001, kernel=rbf..........
# [CV 2/5; 21/200] END C=0.21544346900318834, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.230) r2: (test=0.071) total time=   1.5s
# [CV 3/5; 21/200] START C=0.21544346900318834, gamma=0.0001, kernel=rbf..........
# [CV 3/5; 21/200] END C=0.21544346900318834, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.184) r2: (test=0.135) total time=   1.5s
# [CV 4/5; 21/200] START C=0.21544346900318834, gamma=0.0001, kernel=rbf..........
# [CV 4/5; 21/200] END C=0.21544346900318834, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.841) r2: (test=-0.377) total time=   1.4s
# [CV 5/5; 21/200] START C=0.21544346900318834, gamma=0.0001, kernel=rbf..........
# [CV 5/5; 21/200] END C=0.21544346900318834, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.674) r2: (test=0.030) total time=   1.4s
# [CV 1/5; 22/200] START C=0.21544346900318834, gamma=0.0001, kernel=poly.........
# [CV 1/5; 22/200] END C=0.21544346900318834, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.540) r2: (test=-0.131) total time=   1.0s
# [CV 2/5; 22/200] START C=0.21544346900318834, gamma=0.0001, kernel=poly.........
# [CV 2/5; 22/200] END C=0.21544346900318834, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.288) r2: (test=-0.018) total time=   1.0s
# [CV 3/5; 22/200] START C=0.21544346900318834, gamma=0.0001, kernel=poly.........
# [CV 3/5; 22/200] END C=0.21544346900318834, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.278) r2: (test=-0.007) total time=   1.2s
# [CV 4/5; 22/200] START C=0.21544346900318834, gamma=0.0001, kernel=poly.........
# [CV 4/5; 22/200] END C=0.21544346900318834, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.690) r2: (test=-0.161) total time=   1.2s
# [CV 5/5; 22/200] START C=0.21544346900318834, gamma=0.0001, kernel=poly.........
# [CV 5/5; 22/200] END C=0.21544346900318834, gamma=0.0001, kernel=poly; neg_root_mean_squared_error: (test=-1.830) r2: (test=-0.160) total time=   1.1s
# [CV 1/5; 23/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf
# [CV 1/5; 23/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.405) r2: (test=0.059) total time=   1.5s
# [CV 2/5; 23/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf
# [CV 2/5; 23/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.239) r2: (test=0.057) total time=   1.4s
# [CV 3/5; 23/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf
# [CV 3/5; 23/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.191) r2: (test=0.124) total time=   1.4s
# [CV 4/5; 23/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf
# [CV 4/5; 23/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.858) r2: (test=-0.403) total time=   1.4s
# [CV 5/5; 23/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf
# [CV 5/5; 23/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=rbf; neg_root_mean_squared_error: (test=-1.656) r2: (test=0.051) total time=   1.4s
# [CV 1/5; 24/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly
# [CV 1/5; 24/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.496) r2: (test=-0.068) total time=   1.1s
# [CV 2/5; 24/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly
# [CV 2/5; 24/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.276) r2: (test=0.001) total time=   1.2s
# [CV 3/5; 24/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly
# [CV 3/5; 24/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.260) r2: (test=0.021) total time=   1.1s
# [CV 4/5; 24/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly
# [CV 4/5; 24/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.681) r2: (test=-0.149) total time=   1.1s
# [CV 5/5; 24/200] START C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly
# [CV 5/5; 24/200] END C=0.21544346900318834, gamma=0.00021544346900318845, kernel=poly; neg_root_mean_squared_error: (test=-1.750) r2: (test=-0.060) total time=   1.1s
# [CV 1/5; 25/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf
# [CV 1/5; 25/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.448) r2: (test=0.000) total time=   1.4s
# [CV 2/5; 25/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf
# [CV 2/5; 25/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.247) r2: (test=0.045) total time=   1.4s
# [CV 3/5; 25/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf
# [CV 3/5; 25/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.205) r2: (test=0.104) total time=   1.4s
# [CV 4/5; 25/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf
# [CV 4/5; 25/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.875) r2: (test=-0.429) total time=   1.4s
# [CV 5/5; 25/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf
# [CV 5/5; 25/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=rbf; neg_root_mean_squared_error: (test=-1.653) r2: (test=0.054) total time=   1.6s
# [CV 1/5; 26/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly
# [CV 1/5; 26/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.460) r2: (test=-0.017) total time=   1.2s
# [CV 2/5; 26/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly
# [CV 2/5; 26/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.270) r2: (test=0.010) total time=   1.1s
# [CV 3/5; 26/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly
# [CV 3/5; 26/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.243) r2: (test=0.047) total time=   1.1s
# [CV 4/5; 26/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly
# [CV 4/5; 26/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.718) r2: (test=-0.199) total time=   1.1s
# [CV 5/5; 26/200] START C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly
# [CV 5/5; 26/200] END C=0.21544346900318834, gamma=0.00046415888336127773, kernel=poly; neg_root_mean_squared_error: (test=-1.622) r2: (test=0.089) total time=   1.0s
# [CV 1/5; 27/200] START C=0.21544346900318834, gamma=0.001, kernel=rbf...........
# [CV 1/5; 27/200] END C=0.21544346900318834, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.482) r2: (test=-0.047) total time=   1.4s
# [CV 2/5; 27/200] START C=0.21544346900318834, gamma=0.001, kernel=rbf...........
# [CV 2/5; 27/200] END C=0.21544346900318834, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.241) r2: (test=0.054) total time=   1.4s
# [CV 3/5; 27/200] START C=0.21544346900318834, gamma=0.001, kernel=rbf...........
# [CV 3/5; 27/200] END C=0.21544346900318834, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.221) r2: (test=0.079) total time=   1.5s
# [CV 4/5; 27/200] START C=0.21544346900318834, gamma=0.001, kernel=rbf...........
# [CV 4/5; 27/200] END C=0.21544346900318834, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.892) r2: (test=-0.455) total time=   1.4s
# [CV 5/5; 27/200] START C=0.21544346900318834, gamma=0.001, kernel=rbf...........
# [CV 5/5; 27/200] END C=0.21544346900318834, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.719) r2: (test=-0.023) total time=   1.4s
# [CV 1/5; 28/200] START C=0.21544346900318834, gamma=0.001, kernel=poly..........
# [CV 1/5; 28/200] END C=0.21544346900318834, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.461) r2: (test=-0.017) total time=   1.1s
# [CV 2/5; 28/200] START C=0.21544346900318834, gamma=0.001, kernel=poly..........
# [CV 2/5; 28/200] END C=0.21544346900318834, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.295) r2: (test=-0.030) total time=   1.1s
# [CV 3/5; 28/200] START C=0.21544346900318834, gamma=0.001, kernel=poly..........
# [CV 3/5; 28/200] END C=0.21544346900318834, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.393) r2: (test=-0.198) total time=   1.1s
# [CV 4/5; 28/200] START C=0.21544346900318834, gamma=0.001, kernel=poly..........
# [CV 4/5; 28/200] END C=0.21544346900318834, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.763) r2: (test=-0.263) total time=   1.1s
# [CV 5/5; 28/200] START C=0.21544346900318834, gamma=0.001, kernel=poly..........
# [CV 5/5; 28/200] END C=0.21544346900318834, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-1.728) r2: (test=-0.033) total time=   1.1s
# [CV 1/5; 29/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf
# [CV 1/5; 29/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.479) r2: (test=-0.043) total time=   1.4s
# [CV 2/5; 29/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf
# [CV 2/5; 29/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.226) r2: (test=0.077) total time=   1.6s
# [CV 3/5; 29/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf
# [CV 3/5; 29/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.223) r2: (test=0.076) total time=   1.5s
# [CV 4/5; 29/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf
# [CV 4/5; 29/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.879) r2: (test=-0.436) total time=   1.5s
# [CV 5/5; 29/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf
# [CV 5/5; 29/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.793) r2: (test=-0.113) total time=   1.4s
# [CV 1/5; 30/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly
# [CV 1/5; 30/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-1.613) r2: (test=-0.240) total time=   1.9s
# [CV 2/5; 30/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly
# [CV 2/5; 30/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-1.372) r2: (test=-0.156) total time=   2.0s
# [CV 3/5; 30/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly
# [CV 3/5; 30/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-1.564) r2: (test=-0.509) total time=   1.9s
# [CV 4/5; 30/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly
# [CV 4/5; 30/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-1.857) r2: (test=-0.402) total time=   2.1s
# [CV 5/5; 30/200] START C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly
# [CV 5/5; 30/200] END C=0.21544346900318834, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-2.149) r2: (test=-0.599) total time=   1.8s
# [CV 1/5; 31/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf
# [CV 1/5; 31/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.481) r2: (test=-0.046) total time=   1.4s
# [CV 2/5; 31/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf
# [CV 2/5; 31/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.235) r2: (test=0.063) total time=   1.4s
# [CV 3/5; 31/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf
# [CV 3/5; 31/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.243) r2: (test=0.047) total time=   1.4s
# [CV 4/5; 31/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf
# [CV 4/5; 31/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.797) r2: (test=-0.313) total time=   1.4s
# [CV 5/5; 31/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf
# [CV 5/5; 31/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.809) r2: (test=-0.133) total time=   1.6s
# [CV 1/5; 32/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly
# [CV 1/5; 32/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-2.667) r2: (test=-2.390) total time=   6.9s
# [CV 2/5; 32/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly
# [CV 2/5; 32/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-2.035) r2: (test=-1.544) total time=   6.4s
# [CV 3/5; 32/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly
# [CV 3/5; 32/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-2.312) r2: (test=-2.297) total time=   6.1s
# [CV 4/5; 32/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly
# [CV 4/5; 32/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-2.487) r2: (test=-1.513) total time=   6.9s
# [CV 5/5; 32/200] START C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly
# [CV 5/5; 32/200] END C=0.21544346900318834, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-4.010) r2: (test=-4.566) total time=   6.4s
# [CV 1/5; 33/200] START C=0.21544346900318834, gamma=0.01, kernel=rbf............
# [CV 1/5; 33/200] END C=0.21544346900318834, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.541) r2: (test=-0.132) total time=   1.5s
# [CV 2/5; 33/200] START C=0.21544346900318834, gamma=0.01, kernel=rbf............
# [CV 2/5; 33/200] END C=0.21544346900318834, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.286) r2: (test=-0.015) total time=   1.6s
# [CV 3/5; 33/200] START C=0.21544346900318834, gamma=0.01, kernel=rbf............
# [CV 3/5; 33/200] END C=0.21544346900318834, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.281) r2: (test=-0.012) total time=   1.4s
# [CV 4/5; 33/200] START C=0.21544346900318834, gamma=0.01, kernel=rbf............
# [CV 4/5; 33/200] END C=0.21544346900318834, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.698) r2: (test=-0.171) total time=   1.4s
# [CV 5/5; 33/200] START C=0.21544346900318834, gamma=0.01, kernel=rbf............
# [CV 5/5; 33/200] END C=0.21544346900318834, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.838) r2: (test=-0.169) total time=   1.4s
# [CV 1/5; 34/200] START C=0.21544346900318834, gamma=0.01, kernel=poly...........
# [CV 1/5; 34/200] END C=0.21544346900318834, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-3.777) r2: (test=-5.802) total time=  10.3s
# [CV 2/5; 34/200] START C=0.21544346900318834, gamma=0.01, kernel=poly...........
# [CV 2/5; 34/200] END C=0.21544346900318834, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-2.743) r2: (test=-3.622) total time=  12.6s
# [CV 3/5; 34/200] START C=0.21544346900318834, gamma=0.01, kernel=poly...........
# [CV 3/5; 34/200] END C=0.21544346900318834, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-3.610) r2: (test=-7.040) total time=   9.2s
# [CV 4/5; 34/200] START C=0.21544346900318834, gamma=0.01, kernel=poly...........
# [CV 4/5; 34/200] END C=0.21544346900318834, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-2.852) r2: (test=-2.305) total time=  10.6s
# [CV 5/5; 34/200] START C=0.21544346900318834, gamma=0.01, kernel=poly...........
# [CV 5/5; 34/200] END C=0.21544346900318834, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-5.702) r2: (test=-10.256) total time=   9.7s
# [CV 1/5; 35/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf
# [CV 1/5; 35/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.545) r2: (test=-0.138) total time=   1.6s
# [CV 2/5; 35/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf
# [CV 2/5; 35/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.288) r2: (test=-0.019) total time=   1.6s
# [CV 3/5; 35/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf
# [CV 3/5; 35/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.282) r2: (test=-0.015) total time=   1.8s
# [CV 4/5; 35/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf
# [CV 4/5; 35/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.690) r2: (test=-0.160) total time=   1.7s
# [CV 5/5; 35/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf
# [CV 5/5; 35/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.840) r2: (test=-0.172) total time=   1.6s
# [CV 1/5; 36/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly
# [CV 1/5; 36/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.2s
# [CV 2/5; 36/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly
# [CV 2/5; 36/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.4s
# [CV 3/5; 36/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly
# [CV 3/5; 36/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   9.0s
# [CV 4/5; 36/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly
# [CV 4/5; 36/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=  10.3s
# [CV 5/5; 36/200] START C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly
# [CV 5/5; 36/200] END C=0.21544346900318834, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.7s
# [CV 1/5; 37/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf
# [CV 1/5; 37/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.545) r2: (test=-0.138) total time=   2.1s
# [CV 2/5; 37/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf
# [CV 2/5; 37/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.288) r2: (test=-0.019) total time=   2.1s
# [CV 3/5; 37/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf
# [CV 3/5; 37/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.282) r2: (test=-0.015) total time=   2.1s
# [CV 4/5; 37/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf
# [CV 4/5; 37/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.690) r2: (test=-0.160) total time=   2.1s
# [CV 5/5; 37/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf
# [CV 5/5; 37/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.840) r2: (test=-0.172) total time=   2.0s
# [CV 1/5; 38/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly
# [CV 1/5; 38/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.2s
# [CV 2/5; 38/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly
# [CV 2/5; 38/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.2s
# [CV 3/5; 38/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly
# [CV 3/5; 38/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   9.1s
# [CV 4/5; 38/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly
# [CV 4/5; 38/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=   9.7s
# [CV 5/5; 38/200] START C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly
# [CV 5/5; 38/200] END C=0.21544346900318834, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.2s
# [CV 1/5; 39/200] START C=0.21544346900318834, gamma=0.1, kernel=rbf.............
# [CV 1/5; 39/200] END C=0.21544346900318834, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.545) r2: (test=-0.138) total time=   2.0s
# [CV 2/5; 39/200] START C=0.21544346900318834, gamma=0.1, kernel=rbf.............
# [CV 2/5; 39/200] END C=0.21544346900318834, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.288) r2: (test=-0.019) total time=   1.9s
# [CV 3/5; 39/200] START C=0.21544346900318834, gamma=0.1, kernel=rbf.............
# [CV 3/5; 39/200] END C=0.21544346900318834, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.282) r2: (test=-0.015) total time=   1.8s
# [CV 4/5; 39/200] START C=0.21544346900318834, gamma=0.1, kernel=rbf.............
# [CV 4/5; 39/200] END C=0.21544346900318834, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.690) r2: (test=-0.160) total time=   1.9s
# [CV 5/5; 39/200] START C=0.21544346900318834, gamma=0.1, kernel=rbf.............
# [CV 5/5; 39/200] END C=0.21544346900318834, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.840) r2: (test=-0.172) total time=   2.0s
# [CV 1/5; 40/200] START C=0.21544346900318834, gamma=0.1, kernel=poly............
# [CV 1/5; 40/200] END C=0.21544346900318834, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.2s
# [CV 2/5; 40/200] START C=0.21544346900318834, gamma=0.1, kernel=poly............
# [CV 2/5; 40/200] END C=0.21544346900318834, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.6s
# [CV 3/5; 40/200] START C=0.21544346900318834, gamma=0.1, kernel=poly............
# [CV 3/5; 40/200] END C=0.21544346900318834, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   9.0s
# [CV 4/5; 40/200] START C=0.21544346900318834, gamma=0.1, kernel=poly............
# [CV 4/5; 40/200] END C=0.21544346900318834, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=  10.3s
# [CV 5/5; 40/200] START C=0.21544346900318834, gamma=0.1, kernel=poly............
# [CV 5/5; 40/200] END C=0.21544346900318834, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.3s
# [CV 1/5; 41/200] START C=0.46415888336127786, gamma=0.0001, kernel=rbf..........
# [CV 1/5; 41/200] END C=0.46415888336127786, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.386) r2: (test=0.084) total time=   1.5s
# [CV 2/5; 41/200] START C=0.46415888336127786, gamma=0.0001, kernel=rbf..........
# [CV 2/5; 41/200] END C=0.46415888336127786, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.233) r2: (test=0.066) total time=   1.4s
# [CV 3/5; 41/200] START C=0.46415888336127786, gamma=0.0001, kernel=rbf..........
# [CV 3/5; 41/200] END C=0.46415888336127786, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.191) r2: (test=0.125) total time=   1.5s
# [CV 4/5; 41/200] START C=0.46415888336127786, gamma=0.0001, kernel=rbf..........
# [CV 4/5; 41/200] END C=0.46415888336127786, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.854) r2: (test=-0.397) total time=   1.6s
# [CV 5/5; 41/200] START C=0.46415888336127786, gamma=0.0001, kernel=rbf..........
# [CV 5/5; 41/200] END C=0.46415888336127786, gamma=0.0001, kernel=rbf; neg_root_mean_squared_error: (test=-1.651) r2: (test=0.057) total time=   1.5s
# [CV 1/5; 42/200] START C=0.46415888336127786, gamma=0.0001, kernel=poly.........
# ...
# [CV 4/5; 187/200] END C=100.0, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.811) r2: (test=-0.332) total time=   6.1s
# [CV 5/5; 187/200] START C=100.0, gamma=0.001, kernel=rbf........................
# [CV 5/5; 187/200] END C=100.0, gamma=0.001, kernel=rbf; neg_root_mean_squared_error: (test=-1.987) r2: (test=-0.367) total time=   7.5s
# [CV 1/5; 188/200] START C=100.0, gamma=0.001, kernel=poly.......................
# [CV 1/5; 188/200] END C=100.0, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-3.622) r2: (test=-5.253) total time=  10.0s
# [CV 2/5; 188/200] START C=100.0, gamma=0.001, kernel=poly.......................
# [CV 2/5; 188/200] END C=100.0, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-2.662) r2: (test=-3.352) total time=  11.1s
# [CV 3/5; 188/200] START C=100.0, gamma=0.001, kernel=poly.......................
# [CV 3/5; 188/200] END C=100.0, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-3.345) r2: (test=-5.906) total time=   9.9s
# [CV 4/5; 188/200] START C=100.0, gamma=0.001, kernel=poly.......................
# [CV 4/5; 188/200] END C=100.0, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-2.822) r2: (test=-2.236) total time=  10.0s
# [CV 5/5; 188/200] START C=100.0, gamma=0.001, kernel=poly.......................
# [CV 5/5; 188/200] END C=100.0, gamma=0.001, kernel=poly; neg_root_mean_squared_error: (test=-5.475) r2: (test=-9.377) total time=   8.0s
# [CV 1/5; 189/200] START C=100.0, gamma=0.002154434690031882, kernel=rbf.........
# [CV 1/5; 189/200] END C=100.0, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.591) r2: (test=-0.206) total time=   2.7s
# [CV 2/5; 189/200] START C=100.0, gamma=0.002154434690031882, kernel=rbf.........
# [CV 2/5; 189/200] END C=100.0, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.277) r2: (test=-0.001) total time=   2.8s
# [CV 3/5; 189/200] START C=100.0, gamma=0.002154434690031882, kernel=rbf.........
# [CV 3/5; 189/200] END C=100.0, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.339) r2: (test=-0.106) total time=   2.8s
# [CV 4/5; 189/200] START C=100.0, gamma=0.002154434690031882, kernel=rbf.........
# [CV 4/5; 189/200] END C=100.0, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.722) r2: (test=-0.206) total time=   2.6s
# [CV 5/5; 189/200] START C=100.0, gamma=0.002154434690031882, kernel=rbf.........
# [CV 5/5; 189/200] END C=100.0, gamma=0.002154434690031882, kernel=rbf; neg_root_mean_squared_error: (test=-1.733) r2: (test=-0.040) total time=   2.9s
# [CV 1/5; 190/200] START C=100.0, gamma=0.002154434690031882, kernel=poly........
# [CV 1/5; 190/200] END C=100.0, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.5s
# [CV 2/5; 190/200] START C=100.0, gamma=0.002154434690031882, kernel=poly........
# [CV 2/5; 190/200] END C=100.0, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.3s
# [CV 3/5; 190/200] START C=100.0, gamma=0.002154434690031882, kernel=poly........
# [CV 3/5; 190/200] END C=100.0, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   9.0s
# [CV 4/5; 190/200] START C=100.0, gamma=0.002154434690031882, kernel=poly........
# [CV 4/5; 190/200] END C=100.0, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=  10.2s
# [CV 5/5; 190/200] START C=100.0, gamma=0.002154434690031882, kernel=poly........
# [CV 5/5; 190/200] END C=100.0, gamma=0.002154434690031882, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.0s
# [CV 1/5; 191/200] START C=100.0, gamma=0.004641588833612777, kernel=rbf.........
# [CV 1/5; 191/200] END C=100.0, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.517) r2: (test=-0.096) total time=   2.0s
# [CV 2/5; 191/200] START C=100.0, gamma=0.004641588833612777, kernel=rbf.........
# [CV 2/5; 191/200] END C=100.0, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.223) r2: (test=0.081) total time=   1.9s
# [CV 3/5; 191/200] START C=100.0, gamma=0.004641588833612777, kernel=rbf.........
# [CV 3/5; 191/200] END C=100.0, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.325) r2: (test=-0.084) total time=   2.1s
# [CV 4/5; 191/200] START C=100.0, gamma=0.004641588833612777, kernel=rbf.........
# [CV 4/5; 191/200] END C=100.0, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.711) r2: (test=-0.190) total time=   2.0s
# [CV 5/5; 191/200] START C=100.0, gamma=0.004641588833612777, kernel=rbf.........
# [CV 5/5; 191/200] END C=100.0, gamma=0.004641588833612777, kernel=rbf; neg_root_mean_squared_error: (test=-1.721) r2: (test=-0.026) total time=   2.0s
# [CV 1/5; 192/200] START C=100.0, gamma=0.004641588833612777, kernel=poly........
# [CV 1/5; 192/200] END C=100.0, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.3s
# [CV 2/5; 192/200] START C=100.0, gamma=0.004641588833612777, kernel=poly........
# [CV 2/5; 192/200] END C=100.0, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  10.0s
# [CV 3/5; 192/200] START C=100.0, gamma=0.004641588833612777, kernel=poly........
# [CV 3/5; 192/200] END C=100.0, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   8.9s
# [CV 4/5; 192/200] START C=100.0, gamma=0.004641588833612777, kernel=poly........
# [CV 4/5; 192/200] END C=100.0, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=  10.1s
# [CV 5/5; 192/200] START C=100.0, gamma=0.004641588833612777, kernel=poly........
# [CV 5/5; 192/200] END C=100.0, gamma=0.004641588833612777, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.4s
# [CV 1/5; 193/200] START C=100.0, gamma=0.01, kernel=rbf.........................
# [CV 1/5; 193/200] END C=100.0, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.455) r2: (test=-0.010) total time=   2.2s
# [CV 2/5; 193/200] START C=100.0, gamma=0.01, kernel=rbf.........................
# [CV 2/5; 193/200] END C=100.0, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.280) r2: (test=-0.006) total time=   2.1s
# [CV 3/5; 193/200] START C=100.0, gamma=0.01, kernel=rbf.........................
# [CV 3/5; 193/200] END C=100.0, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.358) r2: (test=-0.138) total time=   2.0s
# [CV 4/5; 193/200] START C=100.0, gamma=0.01, kernel=rbf.........................
# [CV 4/5; 193/200] END C=100.0, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.614) r2: (test=-0.058) total time=   2.0s
# [CV 5/5; 193/200] START C=100.0, gamma=0.01, kernel=rbf.........................
# [CV 5/5; 193/200] END C=100.0, gamma=0.01, kernel=rbf; neg_root_mean_squared_error: (test=-1.724) r2: (test=-0.029) total time=   2.0s
# [CV 1/5; 194/200] START C=100.0, gamma=0.01, kernel=poly........................
# [CV 1/5; 194/200] END C=100.0, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.1s
# [CV 2/5; 194/200] START C=100.0, gamma=0.01, kernel=poly........................
# [CV 2/5; 194/200] END C=100.0, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  10.9s
# [CV 3/5; 194/200] START C=100.0, gamma=0.01, kernel=poly........................
# [CV 3/5; 194/200] END C=100.0, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   8.9s
# [CV 4/5; 194/200] START C=100.0, gamma=0.01, kernel=poly........................
# [CV 4/5; 194/200] END C=100.0, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=  10.3s
# [CV 5/5; 194/200] START C=100.0, gamma=0.01, kernel=poly........................
# [CV 5/5; 194/200] END C=100.0, gamma=0.01, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.2s
# [CV 1/5; 195/200] START C=100.0, gamma=0.021544346900318822, kernel=rbf.........
# [CV 1/5; 195/200] END C=100.0, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.454) r2: (test=-0.008) total time=   2.5s
# [CV 2/5; 195/200] START C=100.0, gamma=0.021544346900318822, kernel=rbf.........
# [CV 2/5; 195/200] END C=100.0, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.292) r2: (test=-0.026) total time=   2.5s
# [CV 3/5; 195/200] START C=100.0, gamma=0.021544346900318822, kernel=rbf.........
# [CV 3/5; 195/200] END C=100.0, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.364) r2: (test=-0.147) total time=   2.7s
# [CV 4/5; 195/200] START C=100.0, gamma=0.021544346900318822, kernel=rbf.........
# [CV 4/5; 195/200] END C=100.0, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.581) r2: (test=-0.016) total time=   2.5s
# [CV 5/5; 195/200] START C=100.0, gamma=0.021544346900318822, kernel=rbf.........
# [CV 5/5; 195/200] END C=100.0, gamma=0.021544346900318822, kernel=rbf; neg_root_mean_squared_error: (test=-1.725) r2: (test=-0.030) total time=   2.3s
# [CV 1/5; 196/200] START C=100.0, gamma=0.021544346900318822, kernel=poly........
# [CV 1/5; 196/200] END C=100.0, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.2s
# [CV 2/5; 196/200] START C=100.0, gamma=0.021544346900318822, kernel=poly........
# [CV 2/5; 196/200] END C=100.0, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.4s
# [CV 3/5; 196/200] START C=100.0, gamma=0.021544346900318822, kernel=poly........
# [CV 3/5; 196/200] END C=100.0, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   9.0s
# [CV 4/5; 196/200] START C=100.0, gamma=0.021544346900318822, kernel=poly........
# [CV 4/5; 196/200] END C=100.0, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=  10.2s
# [CV 5/5; 196/200] START C=100.0, gamma=0.021544346900318822, kernel=poly........
# [CV 5/5; 196/200] END C=100.0, gamma=0.021544346900318822, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.7s
# [CV 1/5; 197/200] START C=100.0, gamma=0.046415888336127774, kernel=rbf.........
# [CV 1/5; 197/200] END C=100.0, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.454) r2: (test=-0.008) total time=   3.7s
# [CV 2/5; 197/200] START C=100.0, gamma=0.046415888336127774, kernel=rbf.........
# [CV 2/5; 197/200] END C=100.0, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.292) r2: (test=-0.026) total time=   3.9s
# [CV 3/5; 197/200] START C=100.0, gamma=0.046415888336127774, kernel=rbf.........
# [CV 3/5; 197/200] END C=100.0, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.364) r2: (test=-0.148) total time=   3.9s
# [CV 4/5; 197/200] START C=100.0, gamma=0.046415888336127774, kernel=rbf.........
# [CV 4/5; 197/200] END C=100.0, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.581) r2: (test=-0.016) total time=   3.6s
# [CV 5/5; 197/200] START C=100.0, gamma=0.046415888336127774, kernel=rbf.........
# [CV 5/5; 197/200] END C=100.0, gamma=0.046415888336127774, kernel=rbf; neg_root_mean_squared_error: (test=-1.725) r2: (test=-0.030) total time=   3.4s
# [CV 1/5; 198/200] START C=100.0, gamma=0.046415888336127774, kernel=poly........
# [CV 1/5; 198/200] END C=100.0, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.0s
# [CV 2/5; 198/200] START C=100.0, gamma=0.046415888336127774, kernel=poly........
# [CV 2/5; 198/200] END C=100.0, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.3s
# [CV 3/5; 198/200] START C=100.0, gamma=0.046415888336127774, kernel=poly........
# [CV 3/5; 198/200] END C=100.0, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   9.1s
# [CV 4/5; 198/200] START C=100.0, gamma=0.046415888336127774, kernel=poly........
# [CV 4/5; 198/200] END C=100.0, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=   9.6s
# [CV 5/5; 198/200] START C=100.0, gamma=0.046415888336127774, kernel=poly........
# [CV 5/5; 198/200] END C=100.0, gamma=0.046415888336127774, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.3s
# [CV 1/5; 199/200] START C=100.0, gamma=0.1, kernel=rbf..........................
# [CV 1/5; 199/200] END C=100.0, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.454) r2: (test=-0.008) total time=   3.1s
# [CV 2/5; 199/200] START C=100.0, gamma=0.1, kernel=rbf..........................
# [CV 2/5; 199/200] END C=100.0, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.292) r2: (test=-0.026) total time=   3.1s
# [CV 3/5; 199/200] START C=100.0, gamma=0.1, kernel=rbf..........................
# [CV 3/5; 199/200] END C=100.0, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.364) r2: (test=-0.148) total time=   3.0s
# [CV 4/5; 199/200] START C=100.0, gamma=0.1, kernel=rbf..........................
# [CV 4/5; 199/200] END C=100.0, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.581) r2: (test=-0.016) total time=   3.0s
# [CV 5/5; 199/200] START C=100.0, gamma=0.1, kernel=rbf..........................
# [CV 5/5; 199/200] END C=100.0, gamma=0.1, kernel=rbf; neg_root_mean_squared_error: (test=-1.725) r2: (test=-0.030) total time=   3.7s
# [CV 1/5; 200/200] START C=100.0, gamma=0.1, kernel=poly.........................
# [CV 1/5; 200/200] END C=100.0, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-3.778) r2: (test=-5.804) total time=  10.1s
# [CV 2/5; 200/200] START C=100.0, gamma=0.1, kernel=poly.........................
# [CV 2/5; 200/200] END C=100.0, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-2.749) r2: (test=-3.641) total time=  13.5s
# [CV 3/5; 200/200] START C=100.0, gamma=0.1, kernel=poly.........................
# [CV 3/5; 200/200] END C=100.0, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-3.665) r2: (test=-7.287) total time=   8.9s
# [CV 4/5; 200/200] START C=100.0, gamma=0.1, kernel=poly.........................
# [CV 4/5; 200/200] END C=100.0, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-2.851) r2: (test=-2.304) total time=  10.2s
# [CV 5/5; 200/200] START C=100.0, gamma=0.1, kernel=poly.........................
# [CV 5/5; 200/200] END C=100.0, gamma=0.1, kernel=poly; neg_root_mean_squared_error: (test=-5.707) r2: (test=-10.274) total time=   9.1s
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('pca', PCA(n_components=50)),
#                 ('gridsearchcv',
#                  GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                               estimator=SVR(),
#                               param_grid={'C': array([  0.1       ,   0.21544347,   0.46415888,   1.        ,
#          2.15443469,   4.64158883,  10.        ,  21.5443469 ,
#         46.41588834, 100.        ]),
#                                           'gamma': array([0.0001    , 0.00021544, 0.00046416, 0.001     , 0.00215443,
#        0.00464159, 0.01      , 0.02154435, 0.04641589, 0.1       ]),
#                                           'kernel': ['rbf', 'poly']},
#                               refit=False,
#                               scoring=['neg_root_mean_squared_error', 'r2'],
#                               verbose=10))])

# %%
# Get table of parameters
params = [[params['kernel'], params['C'], params['gamma']] for params in clf.cv_results_['params']] 

keys = ['mean_test_neg_root_mean_squared_error', 'std_test_neg_root_mean_squared_error', 'mean_test_r2', 'std_test_r2']

# Get table of results
results = np.array([clf.cv_results_.get(key) for key in keys])

# Format the metrics for the table and create columns
keys = [key.replace('test_', '').replace('_', ' ') for key in keys]
columns = ['kernel', 'C', 'gamma'] + keys

# Create the final table and dataframe
table = np.hstack([params, results.T])
df = pd.DataFrame(table, columns=columns)
df[keys] = df[keys].astype(float).round(3)
df.iloc[df[['mean neg root mean squared error', 'mean r2']].idxmax()]
# Out:
#   kernel    C   gamma  mean neg root mean squared error  \
# 0    rbf  0.1  0.0001                            -1.455
# 0    rbf  0.1  0.0001                            -1.455
#
#    std neg root mean squared error  mean r2  std r2
# 0                            0.251     -0.0   0.172
# 0                            0.251     -0.0   0.172

# %%
svr = SVR(kernel='rbf', C=0.1, gamma=0.0001)
pipeline = make_pipeline(StandardScaler(), PCA(50), svr)
pipeline.fit(X_train_features, y_train)
y_preds = pipeline.predict(X_test_features)
results = plot_results(y_test, y_preds, title="Support Vector Regression: True Data vs Model Predictions")

new_row = pd.DataFrame([["Support Vector Regression"] + results], columns=results_df.columns)
results_df = pd.concat([results_df, new_row], ignore_index=True)
# Out:
# R² Score: 0.1577
# RMSE: 1.3181
# Pearson Correlation: 0.4029
# Spearman Correlation: 0.4770

# %% [markdown]
# Final results for regression models:

# %%
results_df
# Out:
#                        model        r2      RMSE   Pearson  Spearman
# 0                        OLS -0.008557  1.442298  0.262029  0.255963
# 1               RandomForest -0.033607  1.460099  0.226290  0.205908
# 2  Support Vector Regression  0.157667  1.318094  0.402949  0.476990

# %% [markdown]
# The best results were found using a Support Vector Regression model. It was the only one to achieve a positive r2 score and it achieved the lowest RMSE. It also scored the highest correlations on Pearson and Spearman.
#
# # <a id='toc3_'></a>[Question 3](#toc0_)

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision.models import resnet18, resnext50_32x4d
from torch.utils.data import TensorDataset, DataLoader, random_split, Dataset
from sklearn.model_selection import train_test_split
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# I tried many models for this, starting with a basic CNN with several layers. I tried a ResNet with the hope of alleviating the problem of vanishing gradients. Eventually I settled on a pretrained ResNext model which aims to improve on Resnet by including groups of transformations in a layer with more efficient scaling.
